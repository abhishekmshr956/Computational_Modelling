# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import utils
import pickle
from scipy.optimize import minimize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#filename = 'data/forAbhi/All_Data.mat'
filename = 'data/All_Data.mat'
data = scipy.io.loadmat(filename) #complete dataset: velocity 48, contrast 48, Edge velocity 8, Edge contrast 8
T4_arclight = data['data']*100.0
T4_gcamp = data['data2']*100.0
# T4_arclight = T4_arclight[:,0:96]
# T4_gcamp = T4_gcamp[:,0:96]
#first 48 columns [0:47] are orientation velocity data, 
#next 48 columns [48:95] are orientation contrast data,
#next 10 columns [96:105] are edge PDND data

# %%
T4_arclight.shape, T4_gcamp.shape
# Out:
# ((113, 112), (113, 112))

# %%
velocity = [15, 30, 60, 120]
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
#utils.plot_data_twinaxis([T4_arclight, T4_gcamp], fig_size=(15,15),speed=velocity,ylim1=(-0.04,0.10),ylim2=(-0.30,2.60),savefig=False, title='Ori_Vel');
utils.plot_data_twinaxis([T4_arclight[:,0:48], T4_gcamp[:,0:48]], fig_size=(15,15),speed=velocity,ylim1=(-4,10),ylim2=(-30,260),savefig=False, title='Ori_Vel');

# %%
contrast = [100, 50, 20, 10]
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
#utils.plot_data_twinaxis([T4_arclight, T4_gcamp], fig_size=(15,15),speed=velocity,ylim1=(-0.04,0.10),ylim2=(-0.30,2.60),savefig=False, title='Ori_Vel');
utils.plot_data_twinaxis([T4_arclight[:,48:96], T4_gcamp[:,48:96]], fig_size=(15,15),speed=contrast,contrast = True,ylim1=(-4,10),ylim2=(-30,260),savefig=False, title='Ori_Vel');

# %%
velocity=[15,30,60,120]
utils.plot_data_twinaxis([T4_arclight[:,96:104], T4_gcamp[:,96:104]],speed=velocity,c=['k','r'],ylim1=(-4,10),ylim2=(-20,600))

# %%
contrast = [100, 50, 20, 10]
utils.plot_data_twinaxis([T4_arclight[:,104:112], T4_gcamp[:,104:112]],speed=contrast,contrast=True,c=['k','r'],ylim1=(-4,10),ylim2=(-20,600))

# %%
global p_bounds 

#bounds on parameters (tauhp, thres, taulp1, taulp2, gain, shift)
p_bounds = ((0,1000),(-1000,1000),(0,1000),(0,1000),(0,1000),(-10,10))

# #bounds on parameters (thres, tauhp, taulp1, gain1, taulp2, gain2, tshift)
#p_bounds = ((-500,500),(0,500),(0,500),(0,200),(0,500),(0,200),(-10,10)) 
#bounds on parameters (thres,taulp1, gain1, taulp2, gain2, tshift)
#p_bounds = ((-300,350),(0,500),(0,200),(0,500),(0,200),(-10,10))
#p_bounds = ((-1,1),(0,5),(0,200),(0,5),(0,200),(-10,10))
#p_bounds = ((-3,4),(0,1),(0,2),(0,500),(0,5),(0,500),(-10,10))

# #bounds on parameters (thres,hp, taulp1, taulp2, gain, tshift)
# p_bounds = ((-300,350),(0,500),(0,500),(0,500),(0,500),(-10,10))

# #bounds on parameters (thres,hp, taulp, gain, tshift)
# p_bounds = ((-300,350),(0,500),(0,500),(0,500),(-10,10))

# %%
# def Ca_model(x, p, dt=0.0769, plot=False):
#     """x is Arclight data. p is list of parameters. dt is timestep"""
#     (thres, tauhp, taulp, gain, tshift) = p
#     x_highpass = highpass(x.copy(), tauhp/100.0, dt)
#     x_thres = threshold_cut(x_highpass.copy(),thres/100.0)
#     x_thres_lp = lowpass(x_thres.copy(), taulp/100.0, dt)
#     #x_thres_lp2 = lowpass(x_thres, taulp2, dt)
#     x_2 = x_thres_lp * x_thres_lp * gain 
#     y = np.roll(x_2, int(tshift), axis=0)
#     if plot==True:
#         utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
#     return y

# def Ca_model(x, p, dt=0.0769, plot=False):
#     """x is Arclight data. p is list of parameters. dt is timestep"""
#     (thres, tauhp, taulp1, taulp2, gain, tshift) = p
#     x_highpass = highpass(x.copy(), tauhp/100.0, dt)
#     x_thres = threshold_cut(x_highpass.copy(),thres/100.0)
#     x_thres_lp1 = lowpass(x_thres.copy(), taulp1/100.0, dt)
#     x_thres_lp2 = lowpass(x_thres.copy(), taulp2/100.0, dt)
#     #x_thres_lp2 = lowpass(x_thres, taulp2, dt)
#     x_2 = x_thres_lp2 * gain * x_thres_lp1
#     y = np.roll(x_2, int(tshift), axis=0)
#     if plot==True:
#         utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
#     return y

# def Ca_model(x, p, dt=0.0769):
#     """x is Arclight data. p is list of parameters. dt is timestep"""
#     (thres, tauhp, taulp1, gain1, taulp2, gain2, tshift) = p
#     x_thres = threshold_cut(x,thres/100.0)
#     x_thres_bp1 = bandpass(x_thres, tauhp/100, taulp1/100, dt)
#     x_1 = x_thres_bp1 * gain1
#     x_thres_bp2 = bandpass(x_thres, tauhp/100, taulp2/100, dt)
#     x_2 = x_thres_bp2 * gain2
#     y = x_1 + x_2
#     y = np.roll(y, int(tshift), axis=0)
#     return y

# def Ca_model(x, p, dt=0.0769, plot=False):
#     """x is Arclight data. p is list of parameters. dt is timestep"""
#     (thres, taulp1, gain1, taulp2, gain2, tshift) = p
#     x_thres = threshold_cut(x,thres/100.0)
#     #x_thres = threshold_cut(x,thres)#/100.0)
#     x_thres_lp1 = lowpass(x_thres, taulp1/100.0, dt)
#     #x_thres_lp1 = lowpass(x_thres, taulp1, dt)
#     x_1 = x_thres_lp1 * gain1
#     x_thres_lp2 = lowpass(x_thres, taulp2/100.0, dt)
#     #x_thres_lp2 = lowpass(x_thres, taulp2, dt)
#     x_2 = x_thres_lp2 * gain2 * x_1
#     y = x_1 + x_2
#     y = np.roll(y, int(tshift), axis=0)
#     if plot==True:
#         utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
#     return y

# def Ca_model(x, p, dt=0.0769, plot=False):
#     """x is Arclight data. p is list of parameters. dt is timestep"""
#     (thres, tauhp, taulp1, gain1, taulp2, gain2, tshift) = p
#     x_highpass = highpass(x.copy(), tauhp/100.0, dt)
#     x_thres = threshold_cut(x_highpass,thres/100.0)
#     x_thres_lp1 = lowpass(x_thres, taulp1/100.0, dt)
#     x_1 = x_thres_lp1 * gain1
#     x_thres_lp2 = lowpass(x_thres, taulp2/100.0, dt)
#     x_2 = x_thres_lp2 * gain2 
#     x_1 = x_1 * x_2
#     y = x_1 + x_2
#     y = np.roll(y, int(tshift), axis=0)
#     if plot==True:
#         utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
#     return y

def Ca_model(x, p, dt=(1/13.0), plot=False):
    """x is Arclight data. p is list of parameters. dt is timestep"""
    (tauhp, thres, taulp1, taulp2, gain, shift) = p
    x_highpass = highpass(x.copy(), tauhp/100.0, dt)
    x_thres = threshold_cut(x_highpass.copy(), thres/100.0)
    x_thres_lp1 = lowpass(x_thres.copy(), taulp1/100.0, dt)
    x_thres_lp2 = lowpass(x_thres.copy(), taulp2/100.0, dt)
    x_1 = x_thres_lp1 * x_thres_lp2
    x_2 = x_1 * gain
    y = np.roll(x_2, int(shift), axis=0)
    if plot==True:
        utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
    return y

# %%
def lowpass(x, tau, dt):
    y = np.zeros_like(x)
    n = x.shape[0]   #length of time dimension
    alpha = dt / (tau+dt)
    y[0] = x[0]
    for i in np.arange(1,n):
        y[i] = alpha*x[i] + (1-alpha)*y[i-1]
    return y

def highpass(x, tau, dt):
    y = x - lowpass(x, tau, dt)
    return y

def bandpass(x, tauhp, taulp, dt):
    y = highpass(x, tauhp, dt)
    y = lowpass(y, taulp, dt)
    return y

def threshold_cut(x, thres):
    x_copy = x.copy()
    x_copy[x_copy<thres] = 0
    return x_copy 

def create_random_params():
    p = [np.random.uniform(bounds[0], bounds[1]) for bounds in p_bounds]
    #print(p)
    return p  

def calc_error(p):
    T4Ca_model = Ca_model(T4_arclight, p)
    ##error1 = np.sqrt(np.mean((T4_Gcamp-T4Ca_model)**2)) #timeerror
    error1 = np.mean(np.sqrt(np.mean((T4_gcamp[10:100][:]-T4Ca_model[10:100][:])**2,axis=0)))
    #error1 = np.mean(np.mean(np.absolute(T4_gcamp[10:100][:]-T4Ca_model[10:100][:]),axis=0))
    error2 = np.sqrt(np.mean((T4_gcamp.max(axis=0)-T4Ca_model.max(axis=0))**2)) #peakerror
    timeerror = 1.0 #weight for time error
    error = timeerror*error1 + (1.0-timeerror)*error2 #peak error aand time error combined
    return error

def fit_params():
    p = create_random_params() #creates random parameter values
    #options = {'maxiter':5000} #maximum number of iterations
    res = minimize(calc_error, p, tol=1e-10, bounds=p_bounds)#options=options
    success = res.success
    if success:
        print('Optimisation successful')
    else:
        print('Optimisation not succesfull')
    p = res.x
    error = calc_error(p)
    print('Remaining Error: ', format(calc_error(p),".2f"))
    print(res)
    return p, error, success

# %%
def many_runs(n):
    (p_list, err_list) = ([],[]) 
    for i in range(n):
        print('run : '+str(i))
        (par, err, success) = fit_params()
        if success:
            print(par)
            p_list.append(par)
            err_list.append(err)
    return p_list, err_list

# %%
para_list, err_list = many_runs(500)
# Out:
# run : 0
# Optimisation not succesfull
# Remaining Error:  25.66
#       fun: 25.664506543038385
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.002224  ,  0.        ,  0.00140083,  0.0009603 , -0.00215614,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1064
#       nit: 14
#      njev: 152
#    status: 2
#   success: False
#         x: array([147.68275003, 625.43246553, 224.98975703, 429.5515318 ,
#        243.3006168 ,  -6.15210407])
# run : 1
# Optimisation not succesfull
# Remaining Error:  22.28
#       fun: 22.27821975462194
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.70565364e-03,  0.00000000e+00,  4.44799400e-04,  4.29878014e-05,
#         1.20969805e-03, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 553
#       nit: 6
#      njev: 79
#    status: 2
#   success: False
#         x: array([133.52926114, 326.85252616, 395.57425217, 529.56287304,
#        314.41058266,  -5.26162754])
# run : 2
# Optimisation successful
# Remaining Error:  24.70
#       fun: 24.696882924739395
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.20792255e-05, -0.00000000e+00,  3.90798472e-06, -6.39488409e-06,
#         3.90798472e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 707
#       nit: 67
#      njev: 101
#    status: 0
#   success: True
#         x: array([  18.14506843, -755.70900112,   18.14284301,   18.13962716,
#          34.51356215,    2.01462628])
# [  18.14506843 -755.70900112   18.14284301   18.13962716   34.51356215
#     2.01462628]
# run : 3
# Optimisation successful
# Remaining Error:  22.05
#       fun: 22.04809766023299
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.00360814, -0.        ,  0.00041744,  0.0016076 , -0.00229327,
#         0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1295
#       nit: 32
#      njev: 185
#    status: 0
#   success: True
#         x: array([  25.42856249, -108.75363439,  131.03835904,  336.9931524 ,
#         311.95120482,    3.54633204])
# [  25.42856249 -108.75363439  131.03835904  336.9931524   311.95120482
#     3.54633204]
# run : 4
# Optimisation not succesfull
# Remaining Error:  20.12
#       fun: 20.119732436230017
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.07898499, -0.        , -0.0028173 , -0.00079723,  0.00110702,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1505
#       nit: 29
#      njev: 215
#    status: 2
#   success: False
#         x: array([  21.80837478, -154.7425074 ,  135.26873996,  538.6781506 ,
#         877.09661375,    0.9060306 ])
# run : 5
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -909.87508144,  109.4120956 ,  811.25919508,
#         580.04737153,   -4.67782823])
# [   0.         -909.87508144  109.4120956   811.25919508  580.04737153
#    -4.67782823]
# run : 6
# Optimisation not succesfull
# Remaining Error:  27.76
#       fun: 27.779090822153506
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 6.60804220e-05,  0.00000000e+00,  1.70530121e-05, -1.32622802e-03,
#         1.17594813e-04,  0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 917
#       nit: 15
#      njev: 131
#    status: 2
#   success: False
#         x: array([579.25234382, 518.70028621, 385.06440767,   6.14107119,
#         29.83752848,   5.52942449])
# run : 7
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -845.46998938,  282.02998645,  522.34427581,
#         550.17572002,   -2.81138427])
# [   0.         -845.46998938  282.02998645  522.34427581  550.17572002
#    -2.81138427]
# run : 8
# Optimisation successful
# Remaining Error:  27.06
#       fun: 27.05533684632108
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.000135  ,  0.        ,  0.0004075 ,  0.00032934, -0.00050804,
#        -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1015
#       nit: 10
#      njev: 145
#    status: 0
#   success: True
#         x: array([416.91503401, 971.19004445, 156.49288398, 713.98725642,
#        561.481423  ,  -5.47915516])
# [416.91503401 971.19004445 156.49288398 713.98725642 561.481423
#   -5.47915516]
# run : 9
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 42
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([   0.        , -981.53791763,  455.46593375,  763.1440297 ,
#         521.26301315,   -3.18463767])
# [   0.         -981.53791763  455.46593375  763.1440297   521.26301315
#    -3.18463767]
# run : 10
# Optimisation not succesfull
# Remaining Error:  22.58
#       fun: 22.583867316130743
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.01347935,  0.        , -0.00390479, -0.0001485 , -0.0005393 ,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 532
#       nit: 8
#      njev: 76
#    status: 2
#   success: False
#         x: array([ 57.4030575 , 253.66621532,  92.93023864, 576.47594857,
#        269.15223432,   1.45517584])
# run : 11
# Optimisation successful
# Remaining Error:  24.50
#       fun: 24.499833794470753
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.42108535e-06, -0.00000000e+00, -1.06581402e-06, -1.06581402e-06,
#         0.00000000e+00,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 539
#       nit: 49
#      njev: 77
#    status: 0
#   success: True
#         x: array([  20.03485065, -793.90465078,   20.0369619 ,   20.03701608,
#          33.38521948,    1.84632099])
# [  20.03485065 -793.90465078   20.0369619    20.03701608   33.38521948
#     1.84632099]
# run : 12
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0.,  0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 28
#       nit: 3
#      njev: 4
#    status: 0
#   success: True
#         x: array([   0.        , -128.96216511,  183.80510847,  251.59503966,
#         855.72277683,    2.01887444])
# [   0.         -128.96216511  183.80510847  251.59503966  855.72277683
#     2.01887444]
# run : 13
# Optimisation successful
# Remaining Error:  28.04
#       fun: 28.038855553138852
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([5.48539336e-04, 0.00000000e+00, 7.28305726e-05, 1.70530121e-05,
#        1.77280272e-04, 0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1967
#       nit: 24
#      njev: 281
#    status: 0
#   success: True
#         x: array([100.23918802, 535.64100652, 532.63540858, 669.02152104,
#        553.81336858,   5.41326218])
# [100.23918802 535.64100652 532.63540858 669.02152104 553.81336858
#    5.41326218]
# run : 14
# Optimisation successful
# Remaining Error:  25.98
#       fun: 25.976852789282823
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 9.84100908e-05,  0.00000000e+00, -1.06226130e-04,  1.38555724e-05,
#        -2.34479250e-05,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 966
#       nit: 24
#      njev: 138
#    status: 0
#   success: True
#         x: array([6.96657229e+02, 6.12795278e+02, 4.44629226e+01, 7.65725682e+02,
#        9.97791833e+01, 4.91768658e-01])
# [6.96657229e+02 6.12795278e+02 4.44629226e+01 7.65725682e+02
#  9.97791833e+01 4.91768658e-01]
# run : 15
# Optimisation successful
# Remaining Error:  24.49
#       fun: 24.49125277477769
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.48689937e-06, -0.00000000e+00, -1.42108535e-06, -1.42108535e-06,
#         1.77635669e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 833
#       nit: 74
#      njev: 119
#    status: 0
#   success: True
#         x: array([  23.56761436, -460.09313659,   23.55017502,   23.55028283,
#          31.02786754,   -0.70891067])
# [  23.56761436 -460.09313659   23.55017502   23.55028283   31.02786754
#    -0.70891067]
# run : 16
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -590.48269803,  830.51296333,  737.00348331,
#         472.13665705,   -1.35810805])
# [   0.         -590.48269803  830.51296333  737.00348331  472.13665705
#    -1.35810805]
# run : 17
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 42
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([   0.        , -363.06488148,  483.04104684,  898.36404195,
#         440.43574359,   -2.34672937])
# [   0.         -363.06488148  483.04104684  898.36404195  440.43574359
#    -2.34672937]
# run : 18
# Optimisation successful
# Remaining Error:  26.35
#       fun: 26.347232750089955
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         7.10542677e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 595
#       nit: 49
#      njev: 85
#    status: 0
#   success: True
#         x: array([ 109.85867917, -491.94096413,  109.85922217,  109.86025719,
#          31.34607971,   -5.00262268])
# [ 109.85867917 -491.94096413  109.85922217  109.86025719   31.34607971
#    -5.00262268]
# run : 19
# Optimisation successful
# Remaining Error:  25.73
#       fun: 25.725178893365825
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.20268073e-05,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         3.55271591e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 399
#       nit: 45
#      njev: 57
#    status: 0
#   success: True
#         x: array([1000.        ,  880.80985689,  169.99967013,  168.85895353,
#          93.65752752,   -3.82201214])
# [1000.          880.80985689  169.99967013  168.85895353   93.65752752
#    -3.82201214]
# run : 20
# Optimisation not succesfull
# Remaining Error:  18.97
#       fun: 18.967862567466433
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00094928,  0.        , -0.00074181, -0.00053575,  0.00317683,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1351
#       nit: 38
#      njev: 193
#    status: 2
#   success: False
#         x: array([ 230.17777482,   59.91191892,  127.18050667, 1000.        ,
#         158.06002065,   -5.08246124])
# run : 21
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0.,  0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 28
#       nit: 3
#      njev: 4
#    status: 0
#   success: True
#         x: array([   0.        , -605.48202847,  999.52463637,  433.3246723 ,
#         490.41458878,    1.47447563])
# [   0.         -605.48202847  999.52463637  433.3246723   490.41458878
#     1.47447563]
# run : 22
# Optimisation not succesfull
# Remaining Error:  22.89
#       fun: 22.890118420978144
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00036344,  0.        ,  0.0012367 ,  0.00149747, -0.00503206,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1281
#       nit: 14
#      njev: 183
#    status: 2
#   success: False
#         x: array([8.13037861e+01, 2.95751484e+02, 6.01929389e+02, 9.10571204e+01,
#        2.03704070e+02, 5.40198976e-01])
# run : 23
# Optimisation not succesfull
# Remaining Error:  27.28
#       fun: 27.27889190539326
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00630856,  0.        , -0.00058513, -0.00087361,  0.00096243,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1064
#       nit: 9
#      njev: 152
#    status: 2
#   success: False
#         x: array([ 113.82251068,  397.35008134, 1000.        ,  565.16517601,
#         731.01024761,    5.91571003])
# run : 24
# Optimisation successful
# Remaining Error:  25.31
#       fun: 25.311696004264043
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.39726441e-02, -0.00000000e+00,  1.15676266e-03,  9.63139914e-04,
#         8.17123498e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 469
#       nit: 27
#      njev: 67
#    status: 0
#   success: True
#         x: array([  13.82436442, -412.04113103,  149.62994288,  190.75306044,
#         818.70554525,    2.79377854])
# [  13.82436442 -412.04113103  149.62994288  190.75306044  818.70554525
#     2.79377854]
# run : 25
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 28
#       nit: 3
#      njev: 4
#    status: 0
#   success: True
#         x: array([   0.        , -893.49079048,  751.77097792,  824.02741816,
#         627.46794368,   -6.60848319])
# [   0.         -893.49079048  751.77097792  824.02741816  627.46794368
#    -6.60848319]
# run : 26
# Optimisation successful
# Remaining Error:  26.91
#       fun: 26.913340403567044
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.55271591e-07, -0.00000000e+00,  0.00000000e+00, -7.10543182e-07,
#         1.42108535e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 329
#       nit: 32
#      njev: 47
#    status: 0
#   success: True
#         x: array([ 119.58077597, -663.96314557,  119.60150844,  119.59248833,
#          28.67046515,   -6.70674244])
# [ 119.58077597 -663.96314557  119.60150844  119.59248833   28.67046515
#    -6.70674244]
# run : 27
# Optimisation successful
# Remaining Error:  26.95
#       fun: 26.951396259177237
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.77635543e-06,  0.00000000e+00, -1.17239542e-05,  2.84216869e-06,
#        -7.10542172e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 364
#       nit: 25
#      njev: 52
#    status: 0
#   success: True
#         x: array([225.60488732, 741.93736718,  54.42850322, 757.51511165,
#        190.55981429,   2.20988035])
# [225.60488732 741.93736718  54.42850322 757.51511165 190.55981429
#    2.20988035]
# run : 28
# Optimisation successful
# Remaining Error:  24.57
#       fun: 24.570968408042088
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.10062982e-03,  3.27936509e+06,  3.57402713e-04,  6.07514420e-05,
#        -2.22506439e-03, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1176
#       nit: 19
#      njev: 168
#    status: 0
#   success: True
#         x: array([264.03306717, 443.11470729, 140.85952708,  84.47937223,
#         34.91258115,  -1.12057579])
# [264.03306717 443.11470729 140.85952708  84.47937223  34.91258115
#   -1.12057579]
# run : 29
# Optimisation successful
# Remaining Error:  27.76
#       fun: 27.76093815517876
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -7.10542677e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 560
#       nit: 49
#      njev: 80
#    status: 0
#   success: True
#         x: array([ 140.77370627, -484.73609639,  140.76555922,  140.76538434,
#          23.09690295,   -8.74593906])
# [ 140.77370627 -484.73609639  140.76555922  140.76538434   23.09690295
#    -8.74593906]
# run : 30
# Optimisation successful
# Remaining Error:  27.75
#       fun: 27.745993872495998
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.55271086e-07, -0.00000000e+00, -3.55271086e-07, -3.55271086e-07,
#        -3.55271338e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1029
#       nit: 38
#      njev: 147
#    status: 0
#   success: True
#         x: array([ 137.8811883 , -413.33658239,  145.54287209,  145.547725  ,
#          24.65966391,   -8.06793413])
# [ 137.8811883  -413.33658239  145.54287209  145.547725     24.65966391
#    -8.06793413]
# run : 31
# Optimisation not succesfull
# Remaining Error:  20.79
#       fun: 20.786144585976736
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.37264411e-02, -0.00000000e+00, -3.00630607e-02, -7.92254522e-05,
#         1.91846386e-04,  0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 840
#       nit: 19
#      njev: 120
#    status: 2
#   success: False
#         x: array([ 43.38062617, -79.20313453,  50.80781797, 882.74045271,
#        323.00200717,   1.97080268])
# run : 32
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.,  0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 42
#       nit: 2
#      njev: 6
#    status: 0
#   success: True
#         x: array([ 7.10542736e-15,  1.31242646e+02,  1.34407316e+02,  5.81641598e+02,
#         9.21022262e+02, -8.36692876e+00])
# [ 7.10542736e-15  1.31242646e+02  1.34407316e+02  5.81641598e+02
#   9.21022262e+02 -8.36692876e+00]
# run : 33
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -519.70162718,  595.9364656 ,  131.4551643 ,
#         570.6575135 ,   -4.56762051])
# [   0.         -519.70162718  595.9364656   131.4551643   570.6575135
#    -4.56762051]
# run : 34
# Optimisation successful
# Remaining Error:  26.35
#       fun: 26.3472327509697
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271591e-07, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         7.10542677e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 497
#       nit: 43
#      njev: 71
#    status: 0
#   success: True
#         x: array([ 109.85855994, -923.86204716,  109.86486906,  109.86223678,
#          31.34774841,   -5.7507364 ])
# [ 109.85855994 -923.86204716  109.86486906  109.86223678   31.34774841
#    -5.7507364 ]
# run : 35
# Optimisation successful
# Remaining Error:  28.59
#       fun: 28.59249977371787
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.95808364e-05,  0.00000000e+00,  1.62003845e-04, -4.93826810e-05,
#         2.68940212e-04,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 539
#       nit: 7
#      njev: 77
#    status: 0
#   success: True
#         x: array([ 92.39111386, 621.11995985, 112.6392529 , 655.38589019,
#        164.10708521,   9.20565573])
# [ 92.39111386 621.11995985 112.6392529  655.38589019 164.10708521
#    9.20565573]
# run : 36
# Optimisation successful
# Remaining Error:  24.57
#       fun: 24.570277948144376
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.97379874e-06, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         7.10542172e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 497
#       nit: 54
#      njev: 71
#    status: 0
#   success: True
#         x: array([  18.36319965, -820.9545642 ,  165.36596238,  165.37628274,
#         543.66532687,   -1.86177512])
# [  18.36319965 -820.9545642   165.36596238  165.37628274  543.66532687
#    -1.86177512]
# run : 37
# Optimisation not succesfull
# Remaining Error:  26.00
#       fun: 25.998042806103342
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00213056,  0.        , -0.0004313 ,  0.0042899 ,  0.00109459,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 707
#       nit: 9
#      njev: 101
#    status: 2
#   success: False
#         x: array([ 1.14564598e+02,  6.41211336e+02,  9.87793415e+02,  1.29102239e+02,
#         5.32361670e+02, -3.31778482e-01])
# run : 38
# Optimisation successful
# Remaining Error:  25.21
#       fun: 25.21305435583911
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00000000e+00, -0.00000000e+00, -7.10543182e-07,  3.55271591e-07,
#         1.06581402e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 539
#       nit: 52
#      njev: 77
#    status: 0
#   success: True
#         x: array([  88.43481269, -480.26166888,   88.42676936,   88.43129632,
#          33.20744862,   -3.7725056 ])
# [  88.43481269 -480.26166888   88.42676936   88.43129632   33.20744862
#    -3.7725056 ]
# run : 39
# Optimisation not succesfull
# Remaining Error:  24.37
#       fun: 24.388613205857116
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00528679,  0.        , -0.00597424, -0.01195134,  0.0313147 ,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 616
#       nit: 8
#      njev: 88
#    status: 2
#   success: False
#         x: array([242.90694215, 344.42072726, 364.75604573,  72.18213383,
#         76.73047473,   0.7786615 ])
# run : 40
# Optimisation successful
# Remaining Error:  24.84
#       fun: 24.8380647091461
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 469
#       nit: 50
#      njev: 67
#    status: 0
#   success: True
#         x: array([  39.96467388, -775.81392057,  137.21908477,  137.22558609,
#         136.62991181,   -2.81948465])
# [  39.96467388 -775.81392057  137.21908477  137.22558609  136.62991181
#    -2.81948465]
# run : 41
# Optimisation successful
# Remaining Error:  25.52
#       fun: 25.523179588906718
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.10134037e-05,  0.00000000e+00, -2.13162652e-06, -2.13162652e-06,
#         2.13162955e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 854
#       nit: 74
#      njev: 122
#    status: 0
#   success: True
#         x: array([1000.        ,  949.54985558,  152.39462387,  154.03298278,
#         112.65802214,   -2.48653055])
# [1000.          949.54985558  152.39462387  154.03298278  112.65802214
#    -2.48653055]
# run : 42
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -906.26963972,  335.32154508,  577.99653817,
#         494.45399488,   -2.80839537])
# [   0.         -906.26963972  335.32154508  577.99653817  494.45399488
#    -2.80839537]
# run : 43
# Optimisation successful
# Remaining Error:  26.31
#       fun: 26.310474359794835
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.10543182e-07, -0.00000000e+00,  0.00000000e+00,  7.10543182e-07,
#        -1.42108535e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 413
#       nit: 36
#      njev: 59
#    status: 0
#   success: True
#         x: array([ 107.40412877, -398.16356391,  122.12142523,  122.11975917,
#          37.12660463,   -5.99172066])
# [ 107.40412877 -398.16356391  122.12142523  122.11975917   37.12660463
#    -5.99172066]
# run : 44
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0.,  0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -435.38335379,  950.75013886,  549.26409577,
#         896.9021937 ,    1.08511047])
# [   0.         -435.38335379  950.75013886  549.26409577  896.9021937
#     1.08511047]
# run : 45
# Optimisation successful
# Remaining Error:  25.67
#       fun: 25.673801195455667
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.52766567e-04,  0.00000000e+00,  2.46203213e-04,  1.13686748e-05,
#        -2.48689760e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1456
#       nit: 25
#      njev: 208
#    status: 0
#   success: True
#         x: array([1.35293636e+02, 6.60038938e+02, 7.22969649e+01, 4.50875635e+02,
#        1.75186272e+02, 2.97561443e-01])
# [1.35293636e+02 6.60038938e+02 7.22969649e+01 4.50875635e+02
#  1.75186272e+02 2.97561443e-01]
# run : 46
# Optimisation successful
# Remaining Error:  26.67
#       fun: 26.672304340698556
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271338e-07, -0.00000000e+00,  0.00000000e+00, -7.10542677e-07,
#         0.00000000e+00,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1547
#       nit: 139
#      njev: 221
#    status: 0
#   success: True
#         x: array([  10.58748105, -512.3203532 ,   10.58740485,   10.58719973,
#          36.75667991,    9.43116866])
# [  10.58748105 -512.3203532    10.58740485   10.58719973   36.75667991
#     9.43116866]
# run : 47
# Optimisation not succesfull
# Remaining Error:  25.78
#       fun: 25.775658018907002
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.53718675e+06, -4.53718354e+06,  1.76605257e-03,  1.41362365e-03,
#        -1.95363570e-03, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 980
#       nit: 36
#      njev: 140
#    status: 2
#   success: False
#         x: array([  58.63883444, -398.00691763,  223.58669257,  169.41585608,
#         134.68450362,   -4.53759982])
# run : 48
# Optimisation successful
# Remaining Error:  27.99
#       fun: 27.994303401705576
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.0004448 ,  0.        , -0.00012932, -0.00012363,  0.00032934,
#         0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1211
#       nit: 24
#      njev: 173
#    status: 0
#   success: True
#         x: array([146.57194037, 483.61677362, 125.44759111, 129.35544654,
#         34.65316931,   7.68779051])
# [146.57194037 483.61677362 125.44759111 129.35544654  34.65316931
#    7.68779051]
# run : 49
# Optimisation successful
# Remaining Error:  21.67
#       fun: 21.671091990158978
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00283578, -0.        ,  0.00201226,  0.00197424, -0.00129603,
#        -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1547
#       nit: 28
#      njev: 221
#    status: 0
#   success: True
#         x: array([  33.1839901 , -247.20668696,  231.1478351 ,  627.5849226 ,
#         964.05967107,   -2.94433473])
# [  33.1839901  -247.20668696  231.1478351   627.5849226   964.05967107
#    -2.94433473]
# run : 50
# Optimisation not succesfull
# Remaining Error:  27.90
#       fun: 27.898246516970108
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 6.96332318e-05,  0.00000000e+00,  4.68957834e-05,  2.10320483e-04,
#        -8.17123498e-06, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1337
#       nit: 15
#      njev: 191
#    status: 2
#   success: False
#         x: array([103.68311466, 918.85728936, 371.77350677, 156.57182017,
#        665.41950827,  -3.75869736])
# run : 51
# Optimisation successful
# Remaining Error:  25.75
#       fun: 25.745731094988024
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271591e-07, -0.00000000e+00,  0.00000000e+00,  3.55271591e-07,
#         1.06581402e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 581
#       nit: 53
#      njev: 83
#    status: 0
#   success: True
#         x: array([  99.84311449, -573.19213061,   99.84671561,   99.85012037,
#          33.11171195,   -4.31470538])
# [  99.84311449 -573.19213061   99.84671561   99.85012037   33.11171195
#    -4.31470538]
# run : 52
# Optimisation successful
# Remaining Error:  25.21
#       fun: 25.21305436444618
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.10543182e-07, -0.00000000e+00, -3.55271591e-07, -3.55271591e-07,
#         7.10542677e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 546
#       nit: 62
#      njev: 78
#    status: 0
#   success: True
#         x: array([  88.40637458, -527.20153175,   88.44825514,   88.45047068,
#          33.22482479,   -3.90849464])
# [  88.40637458 -527.20153175   88.44825514   88.45047068   33.22482479
#    -3.90849464]
# run : 53
# Optimisation not succesfull
# Remaining Error:  24.14
#       fun: 24.199053898716112
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 6.14193526e-03,  0.00000000e+00, -2.66808586e-04, -4.83168677e-05,
#         7.84793829e-04, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1127
#       nit: 11
#      njev: 161
#    status: 2
#   success: False
#         x: array([117.1829251 , 382.3707214 , 831.36052633, 495.24270917,
#        644.1643273 ,  -6.38676303])
# run : 54
# Optimisation not succesfull
# Remaining Error:  21.13
#       fun: 21.125281511696084
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.37525437e-03,  0.00000000e+00, -1.49213856e-05, -6.03960846e-05,
#         8.99546390e-04, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1456
#       nit: 25
#      njev: 208
#    status: 2
#   success: False
#         x: array([256.20845155, 224.80977086, 615.84524359, 691.27247163,
#        316.11575214,  -9.57112894])
# run : 55
# Optimisation not succesfull
# Remaining Error:  23.11
#       fun: 23.106803448317297
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.10458726, -0.        , -0.0023924 , -0.00248157,  0.00132232,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1155
#       nit: 14
#      njev: 165
#    status: 2
#   success: False
#         x: array([  24.43777536, -208.40105512,  296.18713934,  285.0603513 ,
#         823.49278952,    1.07327402])
# run : 56
# Optimisation not succesfull
# Remaining Error:  21.63
#       fun: 21.655984892371755
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00239204,  0.        ,  0.00036451,  0.00097628, -0.00636647,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 994
#       nit: 13
#      njev: 142
#    status: 2
#   success: False
#         x: array([111.38908055, 305.12596714,  98.4763021 , 430.01767736,
#        127.97223093,  -2.76747932])
# run : 57
# Optimisation successful
# Remaining Error:  26.97
#       fun: 26.966598911636577
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.04287631, -0.        , -0.00110702, -0.00107718,  0.0037005 ,
#         0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 259
#       nit: 20
#      njev: 37
#    status: 0
#   success: True
#         x: array([  80.18801448, -325.5118608 ,  373.48533843,  404.28314011,
#         300.33595399,    1.44634069])
# [  80.18801448 -325.5118608   373.48533843  404.28314011  300.33595399
#     1.44634069]
# run : 58
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -573.14808322,  425.78541614,  907.04655915,
#         539.14797737,   -6.1068204 ])
# [   0.         -573.14808322  425.78541614  907.04655915  539.14797737
#    -6.1068204 ]
# run : 59
# Optimisation not succesfull
# Remaining Error:  27.16
#       fun: 27.158228549584216
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00432294,  0.        , -0.0006434 , -0.00025082,  0.00055422,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 903
#       nit: 15
#      njev: 129
#    status: 2
#   success: False
#         x: array([105.88843378, 345.19709159, 317.39112189, 771.40632329,
#        321.48165974,   8.43186915])
# run : 60
# Optimisation successful
# Remaining Error:  25.80
#       fun: 25.800990401502336
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.04537383, -0.        , -0.00098481, -0.00140119,  0.00331468,
#        -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 182
#       nit: 8
#      njev: 26
#    status: 0
#   success: True
#         x: array([  63.50363382, -880.02671167,  420.26591992,  253.85074335,
#         362.8918287 ,   -2.67096155])
# [  63.50363382 -880.02671167  420.26591992  253.85074335  362.8918287
#    -2.67096155]
# run : 61
# Optimisation successful
# Remaining Error:  26.42
#       fun: 26.416386872155122
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.70530121e-05,  0.00000000e+00, -4.61852412e-06, -5.32906629e-06,
#         6.03960846e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 553
#       nit: 35
#      njev: 79
#    status: 0
#   success: True
#         x: array([1000.        ,  989.17351407,  339.0075698 ,  296.21311304,
#         331.50016857,   -6.90261417])
# [1000.          989.17351407  339.0075698   296.21311304  331.50016857
#    -6.90261417]
# run : 62
# Optimisation successful
# Remaining Error:  25.75
#       fun: 25.745731098410996
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271591e-07, -0.00000000e+00,  3.55271591e-07, -3.55271591e-07,
#         3.55271338e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 511
#       nit: 41
#      njev: 73
#    status: 0
#   success: True
#         x: array([  99.83881769, -804.66760598,   99.85929235,   99.84918786,
#          33.11519327,   -4.24985165])
# [  99.83881769 -804.66760598   99.85929235   99.84918786   33.11519327
#    -4.24985165]
# run : 63
# Optimisation successful
# Remaining Error:  25.21
#       fun: 25.213054358000402
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.06581477e-06, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         7.10542677e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 595
#       nit: 61
#      njev: 85
#    status: 0
#   success: True
#         x: array([  88.44335478, -648.85094721,   88.42274544,   88.42560808,
#          33.2028061 ,   -3.93116049])
# [  88.44335478 -648.85094721   88.42274544   88.42560808   33.2028061
#    -3.93116049]
# run : 64
# Optimisation not succesfull
# Remaining Error:  23.74
#       fun: 23.742194896026678
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.00408491,  0.        ,  0.00044551,  0.00108606,  0.00090665,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 469
#       nit: 6
#      njev: 67
#    status: 2
#   success: False
#         x: array([ 35.39105192,  30.74009765, 794.81032164, 580.80151076,
#        537.00586065,   1.56664242])
# run : 65
# Optimisation successful
# Remaining Error:  27.41
#       fun: 27.410718271678302
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.0198888 , -0.        ,  0.00013642, -0.00722302,  0.00098836,
#         0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 329
#       nit: 26
#      njev: 47
#    status: 0
#   success: True
#         x: array([  49.55729736, -915.83711975,  733.67302767,   34.46979084,
#         153.45266105,    4.99848888])
# [  49.55729736 -915.83711975  733.67302767   34.46979084  153.45266105
#     4.99848888]
# run : 66
# Optimisation not succesfull
# Remaining Error:  17.71
#       fun: 17.70689712377285
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 9.10453859e-03,  0.00000000e+00, -4.05009038e-05, -4.93826810e-05,
#         5.40012051e-05, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 2100
#       nit: 44
#      njev: 300
#    status: 2
#   success: False
#         x: array([ 53.47638568, 157.04548595, 258.56346598, 264.97701677,
#        240.34772765,  -4.02366768])
# run : 67
# Optimisation successful
# Remaining Error:  25.82
#       fun: 25.82007100520541
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 6.35935244e-05,  0.00000000e+00, -7.10542172e-06, -3.62376508e-05,
#        -2.27373495e-05, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1015
#       nit: 29
#      njev: 145
#    status: 0
#   success: True
#         x: array([489.30372779, 495.33654575, 539.81533256, 295.36603455,
#        143.28712962,  -9.67484364])
# [489.30372779 495.33654575 539.81533256 295.36603455 143.28712962
#   -9.67484364]
# run : 68
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 42
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([   0.        , -297.01088229,  459.01400148,  401.57125608,
#         765.71891492,   -1.54936924])
# [   0.         -297.01088229  459.01400148  401.57125608  765.71891492
#    -1.54936924]
# run : 69
# Optimisation successful
# Remaining Error:  26.17
#       fun: 26.172668796077062
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.81596389e-06,  0.00000000e+00, -3.55271591e-07, -3.55271591e-07,
#         7.10542677e-07,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 574
#       nit: 51
#      njev: 82
#    status: 0
#   success: True
#         x: array([1.00000000e+03, 9.04962748e+02, 1.18034357e+02, 1.17845395e+02,
#        5.99420303e+01, 7.45328644e-01])
# [1.00000000e+03 9.04962748e+02 1.18034357e+02 1.17845395e+02
#  5.99420303e+01 7.45328644e-01]
# run : 70
# Optimisation successful
# Remaining Error:  26.67
#       fun: 26.672304341194728
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.55271338e-07, -0.00000000e+00,  7.10542677e-07,  7.10542677e-07,
#         0.00000000e+00,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1099
#       nit: 89
#      njev: 157
#    status: 0
#   success: True
#         x: array([  10.58664132, -867.78319211,   10.58803591,   10.58800084,
#          36.76225121,    9.59512447])
# [  10.58664132 -867.78319211   10.58803591   10.58800084   36.76225121
#     9.59512447]
# run : 71
# Optimisation successful
# Remaining Error:  24.47
#       fun: 24.472888747371695
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.48689937e-06, -0.00000000e+00,  0.00000000e+00, -3.55271086e-07,
#        -1.06581326e-05, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 385
#       nit: 32
#      njev: 55
#    status: 0
#   success: True
#         x: array([ 1.07506137e+01, -4.91641082e+02,  1.41256294e+02,  1.41246224e+02,
#         1.00000000e+03, -3.58971411e-01])
# [ 1.07506137e+01 -4.91641082e+02  1.41256294e+02  1.41246224e+02
#   1.00000000e+03 -3.58971411e-01]
# run : 72
# Optimisation successful
# Remaining Error:  28.49
#       fun: 28.49326436739704
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.26325303e-06,  0.00000000e+00,  6.75016023e-06,  3.41060243e-05,
#        -5.01643130e-04,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 994
#       nit: 41
#      njev: 142
#    status: 0
#   success: True
#         x: array([417.51938525, 678.64563888,  64.36659211, 184.79760099,
#         18.1502501 ,   9.12600012])
# [417.51938525 678.64563888  64.36659211 184.79760099  18.1502501
#    9.12600012]
# run : 73
# Optimisation not succesfull
# Remaining Error:  27.32
#       fun: 27.32058481278059
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.90798195e-05,  1.53234311e+06, -6.75015543e-05, -7.10542172e-06,
#         1.22568699e-04,  0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1288
#       nit: 29
#      njev: 184
#    status: 2
#   success: False
#         x: array([825.83700833, 614.55933374,  30.46853484, 989.40082898,
#         93.83332708,   3.6608875 ])
# run : 74
# Optimisation not succesfull
# Remaining Error:  25.56
#       fun: 25.560231341235717
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.0006775 ,  0.        , -0.00110347,  0.00011724, -0.00313776,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1897
#       nit: 34
#      njev: 271
#    status: 2
#   success: False
#         x: array([162.80078153, 549.91250872,  73.44500014, 130.35161085,
#         44.73393152,  -0.93678827])
# run : 75
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.,  0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([  0.        , 610.89072744, 235.35455602, 638.05933788,
#        800.98209425,  -4.96443166])
# [  0.         610.89072744 235.35455602 638.05933788 800.98209425
#   -4.96443166]
# run : 76
# Optimisation not succesfull
# Remaining Error:  21.70
#       fun: 21.70216731890418
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.0015028 ,  0.        ,  0.00075637,  0.0002025 ,  0.00109921,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1260
#       nit: 16
#      njev: 180
#    status: 2
#   success: False
#         x: array([ 49.05637522,  78.77259598, 737.78881909, 993.35598517,
#        817.11462508,  -2.09090934])
# run : 77
# Optimisation successful
# Remaining Error:  24.50
#       fun: 24.499833794330307
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.77635669e-06, -0.00000000e+00,  0.00000000e+00, -7.10542677e-07,
#         1.06581402e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1071
#       nit: 96
#      njev: 153
#    status: 0
#   success: True
#         x: array([  20.03606555, -348.12540011,   20.03654364,   20.03623767,
#          33.38204778,    1.1844502 ])
# [  20.03606555 -348.12540011   20.03654364   20.03623767   33.38204778
#     1.1844502 ]
# run : 78
# Optimisation successful
# Remaining Error:  26.67
#       fun: 26.672304342238345
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 9.23705480e-06, -0.00000000e+00, -1.42108535e-06, -7.10542677e-07,
#         1.77635669e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1078
#       nit: 93
#      njev: 154
#    status: 0
#   success: True
#         x: array([  10.58848758, -403.87400333,   10.58632274,   10.586525  ,
#          36.75034225,    9.57469069])
# [  10.58848758 -403.87400333   10.58632274   10.586525     36.75034225
#     9.57469069]
# run : 79
# Optimisation successful
# Remaining Error:  25.67
#       fun: 25.66555033690346
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.95399097e-05,  4.89882212e+06, -1.77635543e-06,  4.97379520e-06,
#        -2.34478917e-05, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1281
#       nit: 32
#      njev: 183
#    status: 0
#   success: True
#         x: array([572.37818329, 561.11253373, 205.78678885, 914.74941495,
#        209.96597556,  -8.75902112])
# [572.37818329 561.11253373 205.78678885 914.74941495 209.96597556
#   -8.75902112]
# run : 80
# Optimisation not succesfull
# Remaining Error:  19.12
#       fun: 19.119572487514002
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.17097433e-03, -0.00000000e+00,  2.35544730e-04,  6.39487955e-05,
#         7.38963859e-05, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1778
#       nit: 32
#      njev: 254
#    status: 2
#   success: False
#         x: array([  47.89187209, -169.38442671,  737.53137676,  241.30469035,
#         643.28218011,   -4.17402347])
# run : 81
# Optimisation not succesfull
# Remaining Error:  25.82
#       fun: 25.817445171447048
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00055849, -0.        , -0.00057732,  0.00052829, -0.00112159,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1323
#       nit: 17
#      njev: 189
#    status: 2
#   success: False
#         x: array([  64.01726281, -255.24270815,  331.65222709,  956.79918291,
#         558.6315694 ,   -9.71436859])
# run : 82
# Optimisation successful
# Remaining Error:  25.82
#       fun: 25.81503252256252
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271338e-07, -0.00000000e+00,  3.55271338e-07,  3.55271338e-07,
#         0.00000000e+00,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 616
#       nit: 57
#      njev: 88
#    status: 0
#   success: True
#         x: array([  12.06814957, -524.10088078,   12.06747258,   12.06749238,
#          38.67486973,    6.02857145])
# [  12.06814957 -524.10088078   12.06747258   12.06749238   38.67486973
#     6.02857145]
# run : 83
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0.,  0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -284.55919938,  670.81756267,  203.47321011,
#         706.92510889,    3.74370396])
# [   0.         -284.55919938  670.81756267  203.47321011  706.92510889
#     3.74370396]
# run : 84
# Optimisation not succesfull
# Remaining Error:  26.76
#       fun: 26.75701332512046
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00198952,  0.        ,  0.00027889,  0.00037552, -0.00079368,
#         0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1435
#       nit: 11
#      njev: 205
#    status: 2
#   success: False
#         x: array([141.91369984, 329.58079316, 783.58880491, 521.36454439,
#        342.94075342,   7.43094522])
# run : 85
# Optimisation successful
# Remaining Error:  24.84
#       fun: 24.83806471062228
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.10542677e-07, -0.00000000e+00, -7.10542172e-07, -7.10542172e-07,
#        -7.10542172e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 588
#       nit: 52
#      njev: 84
#    status: 0
#   success: True
#         x: array([  39.95985522, -533.36639742,  137.24332531,  137.2370106 ,
#         136.67714645,   -2.4865841 ])
# [  39.95985522 -533.36639742  137.24332531  137.2370106   136.67714645
#    -2.4865841 ]
# run : 86
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.,  0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 7
#       nit: 0
#      njev: 1
#    status: 0
# ...
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([ 0.00000000e+00, -5.43847437e+02,  8.94063713e+02,  1.41204096e+02,
#         7.51983957e+02,  8.51725877e-01])
# [ 0.00000000e+00 -5.43847437e+02  8.94063713e+02  1.41204096e+02
#   7.51983957e+02  8.51725877e-01]
# run : 472
# Optimisation not succesfull
# Remaining Error:  27.85
#       fun: 27.848559948602322
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.01232046,  0.        , -0.00470628, -0.00351825,  0.00285567,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 945
#       nit: 11
#      njev: 135
#    status: 2
#   success: False
#         x: array([ 98.03842515, 835.75301819, 174.97898637, 532.54709414,
#        844.99985389,  -2.3191575 ])
# run : 473
# Optimisation successful
# Remaining Error:  27.67
#       fun: 27.66891860948505
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.48689760e-05,  0.00000000e+00, -3.80140602e-05, -7.10543182e-06,
#        -1.91846523e-05,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1183
#       nit: 51
#      njev: 169
#    status: 0
#   success: True
#         x: array([623.75670733, 731.40518859,  69.31791576,  84.24673398,
#         17.49159186,   4.33765622])
# [623.75670733 731.40518859  69.31791576  84.24673398  17.49159186
#    4.33765622]
# run : 474
# Optimisation not succesfull
# Remaining Error:  28.48
#       fun: 28.475414928393175
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([1.70885392e-04, 0.00000000e+00, 7.60280124e-05, 1.77635543e-05,
#        5.11590364e-05, 0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1043
#       nit: 10
#      njev: 149
#    status: 2
#   success: False
#         x: array([190.20184208, 534.79612192, 445.72544344, 798.99563338,
#        222.32141799,   9.58459352])
# run : 475
# Optimisation successful
# Remaining Error:  25.96
#       fun: 25.96373818260771
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.13686838e-05, -0.00000000e+00,  0.00000000e+00,  2.13162803e-06,
#         5.40012051e-05,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 665
#       nit: 58
#      njev: 95
#    status: 0
#   success: True
#         x: array([   2.5831276 , -329.16360782,   25.49846649,   25.50034305,
#         999.99882046,    6.43229318])
# [   2.5831276  -329.16360782   25.49846649   25.50034305  999.99882046
#     6.43229318]
# run : 476
# Optimisation not succesfull
# Remaining Error:  22.18
#       fun: 22.18043755129487
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00735482,  0.        , -0.00133085, -0.00038476,  0.00539763,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 525
#       nit: 7
#      njev: 75
#    status: 2
#   success: False
#         x: array([176.70731295, 317.03184795, 609.51868159, 291.69151482,
#        260.45308595,  -3.38055566])
# run : 477
# Optimisation not succesfull
# Remaining Error:  16.79
#       fun: 16.787236221459786
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.07771561e-03, -0.00000000e+00,  5.11946363e-04,  2.72492923e-04,
#         8.38439763e-05, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 742
#       nit: 22
#      njev: 106
#    status: 2
#   success: False
#         x: array([ 37.41255145, -83.51804832, 103.87999609, 772.53679454,
#        473.4509636 ,  -2.5652357 ])
# run : 478
# Optimisation successful
# Remaining Error:  25.75
#       fun: 25.745731094495017
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00000000e+00, -0.00000000e+00,  3.55271591e-07,  3.55271591e-07,
#         0.00000000e+00, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 623
#       nit: 56
#      njev: 89
#    status: 0
#   success: True
#         x: array([  99.84550756, -500.05209208,   99.84545016,   99.84650677,
#          33.10991093,   -4.52202613])
# [  99.84550756 -500.05209208   99.84545016   99.84650677   33.10991093
#    -4.52202613]
# run : 479
# Optimisation not succesfull
# Remaining Error:  28.47
#       fun: 28.467893961024465
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.45661145e-05,  2.64152909e+06,  5.68433738e-06,  6.92779110e-05,
#        -6.99884537e-05,  0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1897
#       nit: 39
#      njev: 271
#    status: 2
#   success: False
#         x: array([454.7911201 , 652.37689512, 822.92552167,  51.21644958,
#         59.99848266,   9.44171995])
# run : 480
# Optimisation successful
# Remaining Error:  24.93
#       fun: 24.93094257135036
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.11590364e-05,  0.00000000e+00, -2.48690114e-06,  3.55271086e-06,
#        -7.10542172e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1253
#       nit: 33
#      njev: 179
#    status: 0
#   success: True
#         x: array([539.40619789, 731.97412899,  71.70647783, 873.80751096,
#        182.75550614,  -2.56611472])
# [539.40619789 731.97412899  71.70647783 873.80751096 182.75550614
#   -2.56611472]
# run : 481
# Optimisation successful
# Remaining Error:  28.53
#       fun: 28.53146559101245
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.47979570e-04,  0.00000000e+00,  1.90070301e-04, -7.28305726e-05,
#         5.57775605e-05,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1414
#       nit: 15
#      njev: 202
#    status: 0
#   success: True
#         x: array([ 84.04385543, 903.08245353,  86.71387035, 303.24356508,
#        703.73236851,   4.99927688])
# [ 84.04385543 903.08245353  86.71387035 303.24356508 703.73236851
#    4.99927688]
# run : 482
# Optimisation successful
# Remaining Error:  26.91
#       fun: 26.913340401528565
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 532
#       nit: 40
#      njev: 76
#    status: 0
#   success: True
#         x: array([ 119.58015611, -499.57545074,  119.59207397,  119.5911936 ,
#          28.66841757,   -6.35788264])
# [ 119.58015611 -499.57545074  119.59207397  119.5911936    28.66841757
#    -6.35788264]
# run : 483
# Optimisation successful
# Remaining Error:  28.93
#       fun: 28.930004984681368
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0., -0.,  0.,  0.,  0.,  0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 21
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([   0.        , -995.59606202,  546.93531108,  653.53035737,
#         324.60790678,    2.07018466])
# [   0.         -995.59606202  546.93531108  653.53035737  324.60790678
#     2.07018466]
# run : 484
# Optimisation successful
# Remaining Error:  25.69
#       fun: 25.685369785679445
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.59347893e-05,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         7.10542172e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 651
#       nit: 51
#      njev: 93
#    status: 0
#   success: True
#         x: array([1000.        ,  924.56961276,  222.73080643,  220.4415976 ,
#         156.71114412,   -4.18702882])
# [1000.          924.56961276  222.73080643  220.4415976   156.71114412
#    -4.18702882]
# run : 485
# Optimisation successful
# Remaining Error:  26.81
#       fun: 26.807956254605557
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 9.98313170e-04,  0.00000000e+00, -9.69890065e-05, -6.08935507e-04,
#         3.08020032e-04,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 602
#       nit: 16
#      njev: 86
#    status: 0
#   success: True
#         x: array([ 83.33662372, 458.64911881, 583.89542912,  67.2636827 ,
#        192.89867057,   3.56917695])
# [ 83.33662372 458.64911881 583.89542912  67.2636827  192.89867057
#    3.56917695]
# run : 486
# Optimisation successful
# Remaining Error:  26.35
#       fun: 26.347232750350948
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  1.06581477e-06,
#        -3.55271338e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 497
#       nit: 47
#      njev: 71
#    status: 0
#   success: True
#         x: array([ 109.86130608, -949.02226963,  109.8558082 ,  109.8588346 ,
#          31.34454916,   -5.43353438])
# [ 109.86130608 -949.02226963  109.8558082   109.8588346    31.34454916
#    -5.43353438]
# run : 487
# Optimisation not succesfull
# Remaining Error:  24.23
#       fun: 24.22886142611815
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.33164745e-03,  0.00000000e+00, -2.72492923e-04, -1.01536476e-03,
#        -3.65929219e-05, -0.00000000e+00])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 896
#       nit: 11
#      njev: 128
#    status: 2
#   success: False
#         x: array([122.75472852, 371.51756076, 656.18259775, 330.33556089,
#        367.30655065,  -8.97166303])
# run : 488
# Optimisation successful
# Remaining Error:  25.52
#       fun: 25.52448419808864
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.10542677e-07, -0.00000000e+00, -7.10542677e-07,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 833
#       nit: 67
#      njev: 119
#    status: 0
#   success: True
#         x: array([  13.6439848 , -946.5800107 ,   13.64410623,   13.64423148,
#          36.95378576,    5.61726128])
# [  13.6439848  -946.5800107    13.64410623   13.64423148   36.95378576
#     5.61726128]
# run : 489
# Optimisation not succesfull
# Remaining Error:  18.88
#       fun: 18.883089181829934
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00179838,  0.        ,  0.00066045, -0.00024265,  0.00076596,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 602
#       nit: 16
#      njev: 86
#    status: 2
#   success: False
#         x: array([ 312.70661863,  175.58827199,  140.11568607, 1000.        ,
#         179.86218801,   -5.49667683])
# run : 490
# Optimisation successful
# Remaining Error:  28.42
#       fun: 28.419690444888328
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.53174702e-05,  0.00000000e+00, -6.39488864e-06, -7.10542172e-07,
#         5.79092282e-05,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 896
#       nit: 16
#      njev: 128
#    status: 0
#   success: True
#         x: array([242.1085337 , 571.21475306,  81.5587506 , 155.81590532,
#         20.75196288,   9.84438103])
# [242.1085337  571.21475306  81.5587506  155.81590532  20.75196288
#    9.84438103]
# run : 491
# Optimisation not succesfull
# Remaining Error:  25.77
#       fun: 25.789194323793748
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00345182, -0.        ,  0.00025615,  0.00012008, -0.00094147,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 763
#       nit: 15
#      njev: 109
#    status: 2
#   success: False
#         x: array([  64.56749971, -256.97387165,  559.90390959,  492.79633896,
#         492.26936495,   -9.1661632 ])
# run : 492
# Optimisation not succesfull
# Remaining Error:  19.09
#       fun: 19.168618522355935
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00567546,  0.        ,  0.00099156,  0.00293135, -0.00187157,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1050
#       nit: 19
#      njev: 150
#    status: 2
#   success: False
#         x: array([ 42.38562217, 181.29133346, 456.25619903, 111.28052749,
#        313.16783551,  -0.55610512])
# run : 493
# Optimisation successful
# Remaining Error:  25.52
#       fun: 25.524484200108425
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.06581402e-06, -0.00000000e+00,  1.06581402e-06,  1.06581402e-06,
#         0.00000000e+00,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 917
#       nit: 79
#      njev: 131
#    status: 0
#   success: True
#         x: array([  13.6426198 , -920.41700259,   13.64583837,   13.64588324,
#          36.96177226,    5.64781445])
# [  13.6426198  -920.41700259   13.64583837   13.64588324   36.96177226
#     5.64781445]
# run : 494
# Optimisation successful
# Remaining Error:  28.04
#       fun: 28.039615003181115
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271086e-07, -0.00000000e+00,  3.55271086e-07,  0.00000000e+00,
#         7.10542677e-07, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 448
#       nit: 38
#      njev: 64
#    status: 0
#   success: True
#         x: array([ 152.05216424, -533.94440947,  152.02893598,  152.02649161,
#          20.76359149,   -9.81634246])
# [ 152.05216424 -533.94440947  152.02893598  152.02649161   20.76359149
#    -9.81634246]
# run : 495
# Optimisation successful
# Remaining Error:  25.21
#       fun: 25.21305438902454
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.55271591e-07, -0.00000000e+00, -4.26325909e-06, -2.13162955e-06,
#         7.81596945e-06, -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 721
#       nit: 68
#      njev: 103
#    status: 0
#   success: True
#         x: array([  88.41057827, -819.69326775,   88.42681635,   88.45083845,
#          33.21948608,   -3.20886814])
# [  88.41057827 -819.69326775   88.42681635   88.45083845   33.21948608
#    -3.20886814]
# run : 496
# Optimisation successful
# Remaining Error:  28.20
#       fun: 28.19984907370781
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.81596389e-06,  0.00000000e+00,  3.73034905e-05,  1.77635543e-06,
#         1.77635795e-06,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1540
#       nit: 41
#      njev: 220
#    status: 0
#   success: True
#         x: array([660.9305957 , 876.61629369,  58.14513357, 471.96657155,
#         78.05952704,   6.23346318])
# [660.9305957  876.61629369  58.14513357 471.96657155  78.05952704
#    6.23346318]
# run : 497
# Optimisation successful
# Remaining Error:  27.65
#       fun: 27.64876950535174
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.84216869e-06,  0.00000000e+00,  2.06057376e-05,  7.46069281e-06,
#        -2.38031628e-05,  0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 266
#       nit: 17
#      njev: 38
#    status: 0
#   success: True
#         x: array([996.10480977, 990.28703321,  60.45707353, 896.28347684,
#        252.08677203,   3.20386052])
# [996.10480977 990.28703321  60.45707353 896.28347684 252.08677203
#    3.20386052]
# run : 498
# Optimisation not succesfull
# Remaining Error:  24.50
#       fun: 24.49552932474236
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.0002796 ,  0.        , -0.00530065, -0.00038689,  0.00174509,
#        -0.        ])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 1386
#       nit: 34
#      njev: 198
#    status: 2
#   success: False
#         x: array([452.15420134, 580.19260705,  72.04442621, 460.60625821,
#         86.43545089,  -3.13156724])
# run : 499
# Optimisation successful
# Remaining Error:  27.55
#       fun: 27.553831103643613
#  hess_inv: <6x6 LbfgsInvHessProduct with dtype=float64>
#       jac: array([7.10542172e-07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.10542677e-07, 0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 385
#       nit: 37
#      njev: 55
#    status: 0
#   success: True
#         x: array([995.52854059, 809.20227802,  80.34427178,  80.39380434,
#         22.39950109,   3.5440454 ])
# [995.52854059 809.20227802  80.34427178  80.39380434  22.39950109
#    3.5440454 ]

# %%
# model_para = np.load('model_parameters/scipymini_newmodel_alldatasetcombined.npy')
# print(f'(thres, tauhp, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]:.2f}, {model_para[4]/100:.2f}, {model_para[5]:.2f}, {model_para[6]:.2f})')
# #print(f'(thres, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
# Out:
# (thres, tauhp, taulp1, gain1, taulp2, gain2, tshift) = (0.88, 0.23,1.72, 5.16, 1.72, 53.65, -2.87)

# %%
np.argmin(err_list)
# Out:
# 159

# %%
# model_para = para_list[np.argmin(err_list)]
# print(np.min(err_list))
# #print(f'(thres, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
# print(f'(thres, tauhp, taulp, gain, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]:.2f}, {model_para[4]:.2f})')
# #print(model_para/100) # (thres, taulp1, gain1, taulp2, gain2, tshift)

# %%
# model_para = para_list[np.argmin(err_list)]
# print(np.min(err_list))
# #print(f'(thres, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
# print(f'(thres, tauhp, taulp1, taulp2, gain, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
# #print(model_para/100) # (thres, taulp1, gain1, taulp2, gain2, tshift)

# %%
model_para = para_list[np.argmin(err_list)]
print(np.min(err_list))
#print(f'(thres, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
#print(f'(thres, tauhp, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]:.2f}, {model_para[4]/100:.2f}, {model_para[5]:.2f}, {model_para[6]:.2f})')
print(f'(tauhp, thres, taulp1, taulp2, gain, shift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')

#print(model_para/100) # (thres, taulp1, gain1, taulp2, gain2, tshift)
# Out:
# 17.524627514149294
# (tauhp, thres, taulp1, taulp2, gain, shift) = (0.51, 0.55,0.80, 9.56, 340.24, -2.83)

# %%
#model_p = fit_params()
T4Ca_model = Ca_model(T4_arclight, model_para, plot=False)
#plot_data([T4_Gcamp, T4Ca_model])

# %%
np.mean(np.sqrt(np.mean((T4_gcamp[10:100][:]-T4Ca_model[10:100][:])**2,axis=0)))
# Out:
# 17.524627514149294

# %%
# T4_gcamp = T4_gcamp / 100.0
# T4Ca_model = T4Ca_model / 100.0

# %%
velocity = [15, 30, 60, 120]
utils.plot_data([T4_gcamp[:100,0:48], T4Ca_model[:100,0:48]], ori=True,label=['GCaMP','Model'],c=['r','g'],fig_size=(15,15),speed=velocity,savefig=False, title='Ori_Vel');
#utils.plot_data_twinaxis([T4_gcamp[0:107,0:48], T4Ca_model[0:107,0:48]],speed=velocity,c=['r','g'])
#plt.savefig('figures/scipymini_wholedatasetfit/Ori_Velocity_model.pdf',dpi=1000)

# %%
contrast = [100, 50, 20, 10]
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
#utils.plot_data_twinaxis([T4_arclight, T4_gcamp], fig_size=(15,15),speed=velocity,ylim1=(-0.04,0.10),ylim2=(-0.30,2.60),savefig=False, title='Ori_Vel');
utils.plot_data([T4_gcamp[:100,48:96], T4Ca_model[:100,48:96]], ori=True,contrast=True,label=['GCaMP','Model'],c=['r','g'], fig_size=(15,15),speed=contrast,savefig=False, title='Ori_Vel');
#plt.savefig('figures/scipymini_wholedatasetfit/Ori_Contrast_model.pdf',dpi=1000)

# %%
velocity=[15,30,60,120]
utils.plot_data([T4_gcamp[:,96:104], T4Ca_model[:,96:104]], label=['GCaMP','Model'],c=['r','g'],speed=velocity)
#plt.savefig('figures/scipymini_wholedatasetfit/EdgePDND_model.pdf',dpi=1000)

# %%
contrast = [100, 50, 20, 10]
utils.plot_data([T4_gcamp[:,104:112], T4Ca_model[:,104:112]], label=['GCaMP','Model'],speed=contrast,contrast=True,c=['r','g'])

# %%
data_list = [T4_gcamp[:,96:104], T4Ca_model[:,96:104]]
velocity = [15, 30, 60, 120]
utils.plot_modelpeaktuning(data_list, speed=velocity, ylim1=(0,600),ylim2=(0.0,600.0),color=['r','g'],title='',savefig=False)
#plt.savefig('figures/scipymini_wholedatasetfit/EdgePDND_peaktuning.pdf',dpi=1000)

# %%
velocity=[15,30,60,120]
utils.plot_data([T4_gcamp[:110,[16,17,18,19,40,41,42,43]], T4Ca_model[:110,[16,17,18,19,40,41,42,43]]], label=['GCaMP','Model'],c=['r','g'],speed=velocity)
#plt.savefig('figures/scipymini_wholedatasetfit/GratingsPDND_model.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:110,[16,17,18,19,40,41,42,43]], T4Ca_model[:110,[16,17,18,19,40,41,42,43]]]
velocity = [15, 30, 60, 120]
utils.plot_modelpeaktuning(data_list, speed=velocity, ylim1=(0,280),ylim2=(0.0,280),color=['r','g'],title='',savefig=False)
#plt.savefig('figures/scipymini_wholedatasetfit/GratingsPDND_peaktuning.pdf',dpi=1000)

# %%
contrast=[10,20,50,100]
utils.plot_data([T4_gcamp[:110,[67,66,65,64,91,90,89,88]], T4Ca_model[:110,[67,66,65,64,91,90,89,88]]], label=['GCaMP','Model'],c=['r','g'],speed=contrast,contrast=True)
#plt.savefig('figures/scipymini_wholedatasetfit/ContrastPDND_model.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:110,[67,66,65,64,91,90,89,88]], T4Ca_model[:110,[67,66,65,64,91,90,89,88]]]
contrast = [10,20,50,100]
utils.plot_modelpeaktuning(data_list, speed=contrast, contrast=True,ylim1=(0,280),ylim2=(0.0,280),color=['r','g'],title='',savefig=False)
#plt.savefig('figures/scipymini_wholedatasetfit/ContrastPDND_peaktuning.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:,0:48], T4Ca_model[:,0:48]]
velocity = [15, 30, 60, 120]
peak_tuning = utils.calc_peaktuning(data_list, speed=velocity)
utils.plot_oripeaktuning(data_list,speed=velocity, label=['GCaMP','Model'],fig_size=(15,4), ylim1=(0.0,1.1),ylim2=(0.0,1.1),color=['r','g'],title='Speed_Ori_Tuning');
#plt.savefig('figures/scipymini_wholedatasetfit/OriVelPolar_model.pdf',dpi=1000)

# %%
utils.plot_Ldir_mag(peak_tuning, title='Ldir_Speed_Ori_Tuning',savefig=False);
#plt.savefig('figures/scipymini_wholedatasetfit/OriVelLdir_model.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:,48:96], T4Ca_model[:,48:96]]
#velocity = [15, 30, 60, 120]
contrast = [10, 20, 50, 100]
peak_tuning = utils.calc_peaktuning(data_list, speed=contrast, contrast=True)
utils.plot_oripeaktuning(data_list,speed=contrast, label=['GCaMP','Model'],contrast=True,fig_size=(15,4), ylim1=(0.0,1.1),ylim2=(0.0,1.1),color=['r','g'],title='Speed_Ori_Tuning');
#plt.savefig('figures/scipymini_wholedatasetfit/OriContrastPolar_model.pdf',dpi=1000)

# %%
utils.plot_Ldir_mag(peak_tuning, title='',contrast=True,savefig=False);
#plt.savefig('figures/scipymini_wholedatasetfit/OriContrastLdir_model.pdf',dpi=1000)

# %%
save_para = True
if save_para:
    np.save('model_parameters/scipymini_newmodel_alldatasetcombined.npy',model_para)
