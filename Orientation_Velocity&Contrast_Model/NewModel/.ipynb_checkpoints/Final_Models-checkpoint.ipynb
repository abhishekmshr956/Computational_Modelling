# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import utils
import pickle
from scipy.optimize import minimize

# %%
# ### GCaMP8f dataset
# filename = 'data/All_Data_withGC8.mat'
# data = scipy.io.loadmat(filename)
# T4_arclight = data['data']*100.0
# T4_gcamp6 = data['data2']*100.0
# T4_gcamp8 = data['data8']*100.0

# %%
# #### GCaMP6f complete dataset
# filename = 'data/All_Data.mat'
# data = scipy.io.loadmat(filename) #complete dataset: velocity 48, contrast 48, Edge velocity 8, Edge contrast 8
# T4_arclight = data['data']*100.0
# T4_gcamp = data['data2']*100.0

# %%
# T4c 120deg velocity, contrast data
filename = 'data/forAbhi/Velocity_MeanSEM.mat'
data = scipy.io.loadmat(filename)
arclight_velocity_mean = data['Arcmean'][:,16:20]
gcamp_velocity_mean = data['Gmean'][:,16:20]

filename = 'data/forAbhi/Contrast_MeanSEM.mat'
data = scipy.io.loadmat(filename)
arclight_contrast_mean = data['Arcmean'][:,16:20]
gcamp_contrast_mean = data['Gmean'][:,16:20]

arclight_mean = np.concatenate([arclight_velocity_mean, arclight_contrast_mean], axis=1)
gcamp_mean = np.concatenate([gcamp_velocity_mean, gcamp_contrast_mean], axis=1)

# gcamp_mean = gcamp_mean - gcamp_mean[5:15][:].mean(axis=0) #bringing baseline to zero
# arclight_mean = arclight_mean - arclight_mean[5:15][:].mean(axis=0)

# %%
# ### New Mi1 dataset velocity and contrast
# filename = 'data/forAbhi/MiTm3_FinalData/Mi1_GratingVelocity.mat'
# data = scipy.io.loadmat(filename)
# arclight_velocity_mean = data['Arcmean'][:,:]
# gcamp_velocity_mean = data['Gmean'][:,:]

# filename = 'data/forAbhi/MiTm3_FinalData/Mi1_GratingContrast.mat'
# data = scipy.io.loadmat(filename)
# arclight_contrast_mean = data['Arcmean'][:,:]
# gcamp_contrast_mean = data['Gmean'][:,:]

# arclight_mean = np.concatenate([arclight_velocity_mean, arclight_contrast_mean], axis=1)
# gcamp_mean = np.concatenate([gcamp_velocity_mean, gcamp_contrast_mean], axis=1)

# gcamp_mean = gcamp_mean - gcamp_mean[5:15][:].mean(axis=0) #bringing baseline to zero
# arclight_mean = arclight_mean - arclight_mean[5:15][:].mean(axis=0)

# %%
# ### New Tm3 dataset velocity and contrast
# filename = 'data/forAbhi/MiTm3_FinalData/Tm3_GratingVelocity.mat'
# data = scipy.io.loadmat(filename)
# arclight_velocity_mean = data['Arcmean'][:,:]
# gcamp_velocity_mean = data['Gmean'][:,:]

# filename = 'data/forAbhi/MiTm3_FinalData/Tm3_GratingContrast.mat'
# data = scipy.io.loadmat(filename)
# arclight_contrast_mean = data['Arcmean'][:,:]
# gcamp_contrast_mean = data['Gmean'][:,:]

# arclight_mean = np.concatenate([arclight_velocity_mean, arclight_contrast_mean], axis=1)
# gcamp_mean = np.concatenate([gcamp_velocity_mean, gcamp_contrast_mean], axis=1)

# gcamp_mean = gcamp_mean - gcamp_mean[5:15][:].mean(axis=0) #bringing baseline to zero
# arclight_mean = arclight_mean - arclight_mean[5:15][:].mean(axis=0)

# %%
arclight_mean.shape, gcamp_mean.shape
# Out:
# ((113, 8), (113, 8))

# %%
# ### Mi1 dataset
# filename = 'data/Grating_Velocity - Mi1.mat'
# data = scipy.io.loadmat(filename)  #4 speed. direction doesn't matter. so only 90 degrees direction
# Mi1_arclight = data['data']*100.0
# Mi1_gcamp = data['data2']*100.0

# %%
#T4_gcamp = T4_gcamp8
#T4_gcamp=Mi1_gcamp
#T4_arclight = Mi1_arclight
#T4_arclight = T4_arclight[:,12:16] #choosing T490deg velocity
#T4_gcamp = T4_gcamp[:, 12:16]
T4_arclight = arclight_mean
T4_gcamp = gcamp_mean
T4_arclight.shape, T4_gcamp.shape #, T4_gcamp6.shape, T4_gcamp8.shape
# Out:
# ((113, 8), (113, 8))

# %%
#plotting Mi1 data
f,ax = plt.subplots(1,4,figsize=(10,5),sharey=True)
ax[0].plot(T4_gcamp[:,0]); ax[1].plot(T4_gcamp[:,1]); ax[2].plot(T4_gcamp[:,2]);ax[3].plot(T4_gcamp[:,3]);

# %%
#plotting Mi1 data
f,ax = plt.subplots(1,4,figsize=(10,5),sharey=True)
ax[0].plot(T4_arclight[:,0]); ax[1].plot(T4_arclight[:,1]); ax[2].plot(T4_arclight[:,2]);ax[3].plot(T4_arclight[:,3]);

# %%
#plotting Mi1 data
f,ax = plt.subplots(1,4,figsize=(10,5),sharey=True)
ax[0].plot(T4_gcamp[:,4]); ax[1].plot(T4_gcamp[:,5]); ax[2].plot(T4_gcamp[:,6]);ax[3].plot(T4_gcamp[:,7]);

# %%
#plotting Mi1 data
f,ax = plt.subplots(1,4,figsize=(10,5),sharey=True)
ax[0].plot(T4_arclight[:,4]); ax[1].plot(T4_arclight[:,5]); ax[2].plot(T4_arclight[:,6]);ax[3].plot(T4_arclight[:,7]);

# %%
velocity = [15, 30, 60, 120]
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
#utils.plot_data_twinaxis([T4_arclight, T4_gcamp], fig_size=(15,15),speed=velocity,ylim1=(-0.04,0.10),ylim2=(-0.30,2.60),savefig=False, title='Ori_Vel');
utils.plot_data_twinaxis([T4_arclight[:,0:48], T4_gcamp[:,0:48]], legend=['Aclight','GCaMP6'],fig_size=(15,15),speed=velocity,ylim1=(-4,10),ylim2=(-30,260),savefig=False, title='Ori_Vel');

# %%
velocity = [15, 30, 60, 120]
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
#utils.plot_data_twinaxis([T4_arclight, T4_gcamp], fig_size=(15,15),speed=velocity,ylim1=(-0.04,0.10),ylim2=(-0.30,2.60),savefig=False, title='Ori_Vel');
utils.plot_data_twinaxis([T4_gcamp6[:,0:48], T4_gcamp8[:,0:48]], legend=['GCaMP6','GCaMP8'],c=['r','b'],fig_size=(15,15),speed=velocity,ylim1=(-30,260),ylim2=(-30,260),savefig=False, title='Ori_Vel');

# %%
velocity=[15,30,60,120]
utils.plot_data_twinaxis([T4_arclight[:,48:], T4_gcamp[:,48:]],speed=velocity,legend=['Aclight','GCaMP6'],c=['k','r'],ylim1=(-4,10),ylim2=(-20,600))
# Out:
# /Volumes/Elements/Project_T4_VoltageCalcium/Modelling/Computational_Modelling/Orientation_Velocity&Contrast_Model/NewModel/utils.py:167: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
velocity=[15,30,60,120]
utils.plot_data_twinaxis([T4_gcamp6[:,48:], T4_gcamp8[:,48:]],speed=velocity,legend=['Aclight','GCaMP8'],c=['r','b'],ylim1=(-20,600),ylim2=(-20,600))

# %%
T4_arclight.min(), T4_arclight.max()
# Out:
# (-0.0293548022436615, 0.07192267308497927)

# %%
global p_bounds 

#bounds on parameters (tauhp, thres, taulp1, taulp2, gain, shift)
#p_bounds = ((0,1000),(T4_arclight.min()*100, T4_arclight.max()*100),(0,300),(0,2000),(0,1000),(-5,0))

#bounds on parameters for simple model (tauhp, thres, taulp, gain, shift)
p_bounds_S = ((0,1000),(T4_arclight.min()*100, T4_arclight.max()*100),(0,2000),(0,1000),(-5,0))

#bounds on parameters for L model (tauhp, thres, taulp1, taulp2, gain1, gain2 shift)
#p_bounds_L = ((0,1000),(T4_arclight.min()*100, T4_arclight.max()*100),(0,300),(0,2000),(0,1000),(0,1000),(-5,0))

#p_bounds = p_bounds_L #for L model
p_bounds = p_bounds_S #for simple model

# %%
def S_model(x, p, dt=(1/13.0), plot=False):
    (tauhp, thres, taulp, gain, shift) = p
    x_highpass = highpass(x.copy(), tauhp/100.0, dt)
    x_thres = threshold_cut(x_highpass.copy(), thres/100.0)
    x_thres_lp = lowpass(x_thres.copy(), taulp/100.0, dt)
    x_2 = x_thres_lp * gain
    y = np.roll(x_2, int(shift), axis=0)
    return y

def M_model(x, p, dt=(1/13.0), plot=False):
    """x is Arclight data. p is list of parameters. dt is timestep"""
    (tauhp, thres, taulp1, taulp2, gain, shift) = p
    x_highpass = highpass(x.copy(), tauhp/100.0, dt)
    x_thres = threshold_cut(x_highpass.copy(), thres/100.0)
    x_thres_lp1 = lowpass(x_thres.copy(), taulp1/100.0, dt)
    x_thres_lp2 = lowpass(x_thres.copy(), taulp2/100.0, dt)
    x_1 = x_thres_lp1 * x_thres_lp2
    x_2 = x_1 * gain
    y = np.roll(x_2, int(shift), axis=0)
    if plot==True:
        utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
    return y

def L_model(x, p, dt=(1/13.0), plot=False):
    """x is Arclight data. p is list of parameters. dt is timestep"""
    (tauhp, thres, taulp1, taulp2, gain1, gain2, shift) = p
    x_highpass = highpass(x.copy(), tauhp/100.0, dt)
    x_thres = threshold_cut(x_highpass.copy(), thres/100.0)
    x_thres_lp1 = lowpass(x_thres.copy(), taulp1/100.0, dt)*gain1
    x_thres_lp2 = lowpass(x_thres.copy(), taulp2/100.0, dt)*gain2
    x_1 = x_thres_lp1 + x_thres_lp2
    y = np.roll(x_1, int(shift), axis=0)
    if plot==True:
        utils.plot_data([x, x_thres, x_1, x_2, y], c=['k','grey','g','brown','r']);
    return y

# %%
def lowpass(x, tau, dt):
    y = np.zeros_like(x)
    n = x.shape[0]   #length of time dimension
    alpha = dt / (tau+dt)
    y[0] = x[0]
    for i in np.arange(1,n):
        y[i] = alpha*x[i] + (1-alpha)*y[i-1]
    return y

def highpass(x, tau, dt):
    y = x - lowpass(x, tau, dt)
    return y

def bandpass(x, tauhp, taulp, dt):
    y = highpass(x, tauhp, dt)
    y = lowpass(y, taulp, dt)
    return y

def threshold_cut(x, thres):
    x_copy = x.copy()
    x_copy[x_copy<thres] = thres
    return x_copy 

def create_random_params():
    p = [np.random.uniform(bounds[0], bounds[1]) for bounds in p_bounds]
    #print(p)
    return p  

def calc_error(p):
    #T4Ca_model = M_model(T4_arclight, p)
    #T4Ca_model = L_model(T4_arclight, p)
    T4Ca_model = S_model(T4_arclight, p)
    
    #error = np.mean(np.sqrt(np.mean((T4_gcamp-T4Ca_model)**2,axis=0)))
    #error = (T4_gcamp[10:100,:]-T4Ca_model[10:100,:])**2
    #error = np.mean(np.sqrt(np.mean((T4_gcamp[10:100,:]-T4Ca_model[10:100,:])**2,axis=0)))/np.mean(np.sqrt(np.mean(T4_gcamp[10:100,:]**2,axis=0)))
    error = np.sum((T4_gcamp[10:100,:]-T4Ca_model[10:100,:])**2)
    return error

def fit_params():
    p = create_random_params() #creates random parameter values
    #options = {'maxiter':5000} #maximum number of iterations
    res = minimize(calc_error, p, bounds=p_bounds)#options=options
    success = res.success
    if success:
        print('Optimisation successful')
    else:
        print('Optimisation not succesfull')
    p = res.x
    error = calc_error(p)
    print('Remaining Error: ', format(calc_error(p),".2f"))
    print(res)
    return p, error, success

# %%
def many_runs(n):
    (p_list, err_list) = ([],[]) 
    for i in range(n):
        print('run : '+str(i))
        (par, err, success) = fit_params()
        if success:
            print(par)
            p_list.append(par)
            err_list.append(err)
    return p_list, err_list

# %%
para_list, err_list = many_runs(300)
# Out:
# run : 0
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611886740276
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00000000e+00,  3.62376795e-05, -3.55271086e-06,  1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 570
#       nit: 63
#      njev: 95
#    status: 0
#   success: True
#         x: array([ 25.73401411,  -0.30701046, 191.41114837, 225.36047361,
#         -2.79064511])
# [ 25.73401411  -0.30701046 191.41114837 225.36047361  -2.79064511]
# run : 1
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725732824577
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.69011458e-03,  3.31622374e-01, -4.97379520e-06,  1.49924398e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 522
#       nit: 42
#      njev: 87
#    status: 0
#   success: True
#         x: array([ 33.21953821,  -0.33315308, 232.3460068 , 220.19334441,
#         -3.73721332])
# [ 33.21953821  -0.33315308 232.3460068  220.19334441  -3.73721332]
# run : 2
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.866118867601614
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.10542677e-07,  2.78532753e-04, -1.42108434e-06, -7.10542172e-07,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 588
#       nit: 67
#      njev: 98
#    status: 0
#   success: True
#         x: array([ 25.73410455,  -0.3070083 , 191.41083382, 225.35954029,
#         -2.32696037])
# [ 25.73410455  -0.3070083  191.41083382 225.35954029  -2.32696037]
# run : 3
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.866118868657324
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.10542677e-07,  6.11066753e-05,  2.84216869e-06, -7.10542172e-07,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 540
#       nit: 62
#      njev: 90
#    status: 0
#   success: True
#         x: array([ 25.73408874,  -0.30701112, 191.4118719 , 225.36054279,
#         -2.0312968 ])
# [ 25.73408874  -0.30701112 191.4118719  225.36054279  -2.0312968 ]
# run : 4
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725762269351
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.96580513e-03,  2.70853207e-01, -7.74490968e-05,  2.60058435e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 900
#       nit: 75
#      njev: 150
#    status: 0
#   success: True
#         x: array([ 33.21812949,  -0.33314254, 232.32516872, 220.1929525 ,
#         -3.06223095])
# [ 33.21812949  -0.33314254 232.32516872 220.1929525   -3.06223095]
# run : 5
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.6546429086977
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-8.52651212e-06, -1.70459202e-02, -1.98951808e-05,  1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 696
#       nit: 63
#      njev: 116
#    status: 0
#   success: True
#         x: array([ 1.59125399e+01, -2.11475659e-01,  1.48019200e+02,  2.48314142e+02,
#        -5.70855388e-01])
# [ 1.59125399e+01 -2.11475659e-01  1.48019200e+02  2.48314142e+02
#  -5.70855388e-01]
# run : 6
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.05460395822276
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-7.10542677e-06,  2.08189022e-04, -2.84216869e-06, -1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 582
#       nit: 55
#      njev: 97
#    status: 0
#   success: True
#         x: array([ 33.96991898,  -0.3279633 , 231.90505495, 217.2147925 ,
#         -3.76140232])
# [ 33.96991898  -0.3279633  231.90505495 217.2147925   -3.76140232]
# run : 7
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.05504717, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 954.60762601,   -2.93548022, 1652.33657204,    0.        ,
#          -4.45394633])
# [ 954.60762601   -2.93548022 1652.33657204    0.           -4.45394633]
# run : 8
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39338199250878
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.73985256e-03,  1.37134748e-03,  1.59161447e-04,  2.13162652e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 858
#       nit: 60
#      njev: 143
#    status: 0
#   success: True
#         x: array([ 17.45369313,  -0.28670503, 166.73034183, 262.02714617,
#         -1.52004684])
# [ 17.45369313  -0.28670503 166.73034183 262.02714617  -1.52004684]
# run : 9
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.01112994, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 5.65214330e+02, -2.93548022e+00,  1.94997014e+03,  0.00000000e+00,
#        -1.21061504e+00])
# [ 5.65214330e+02 -2.93548022e+00  1.94997014e+03  0.00000000e+00
#  -1.21061504e+00]
# run : 10
# Optimisation successful
# Remaining Error:  137.69
#       fun: 137.69075372456618
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.01435579,  0.02351612,  0.01036835,  0.00369766, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 216
#       nit: 23
#      njev: 36
#    status: 0
#   success: True
#         x: array([ 5.74062225e+02,  2.73020779e-02,  1.12442252e+03,  2.62191646e+02,
#        -4.95407840e-01])
# [ 5.74062225e+02  2.73020779e-02  1.12442252e+03  2.62191646e+02
#  -4.95407840e-01]
# run : 11
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464259918956
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.19371170e-04, -1.02261311e-02,  5.68433738e-06, -8.52650607e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 738
#       nit: 67
#      njev: 123
#    status: 0
#   success: True
#         x: array([ 1.59123568e+01, -2.11451840e-01,  1.48020215e+02,  2.48310788e+02,
#        -7.09073110e-01])
# [ 1.59123568e+01 -2.11451840e-01  1.48020215e+02  2.48310788e+02
#  -7.09073110e-01]
# run : 12
# Optimisation successful
# Remaining Error:  53.02
#       fun: 53.02345841825996
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.10134115e-04,  4.39726478e-02,  1.42108434e-06,  2.84216869e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 624
#       nit: 50
#      njev: 104
#    status: 0
#   success: True
#         x: array([ 20.8623892 ,  -0.32755461, 191.76705438, 256.1491231 ,
#         -2.21537247])
# [ 20.8623892   -0.32755461 191.76705438 256.1491231   -2.21537247]
# run : 13
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39338503388572
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.18847145e-03, -2.97501401e-01,  1.57740362e-04, -2.99138254e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 816
#       nit: 63
#      njev: 136
#    status: 0
#   success: True
#         x: array([ 17.43890911,  -0.2865904 , 166.64613045, 262.07327028,
#         -1.07057292])
# [ 17.43890911  -0.2865904  166.64613045 262.07327028  -1.07057292]
# run : 14
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04735533650819
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00701377, -0.3305118 , -0.00053646,  0.00093081, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 576
#       nit: 56
#      njev: 96
#    status: 0
#   success: True
#         x: array([ 33.27466707,  -0.33357444, 232.34543905, 220.14398367,
#         -3.98953954])
# [ 33.27466707  -0.33357444 232.34543905 220.14398367  -3.98953954]
# run : 15
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.054604031087266
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.63424816e-05, -7.06990022e-03,  8.52650607e-06, -2.06057230e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 672
#       nit: 68
#      njev: 112
#    status: 0
#   success: True
#         x: array([ 33.97118247,  -0.327992  , 231.91161472, 217.21722777,
#         -3.10268243])
# [ 33.97118247  -0.327992   231.91161472 217.21722777  -3.10268243]
# run : 16
# Optimisation successful
# Remaining Error:  63.85
#       fun: 63.84572414585786
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.20783373e-02, -2.41006362e+00,  1.18873705e-03,  7.47490365e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 678
#       nit: 45
#      njev: 113
#    status: 0
#   success: True
#         x: array([ 42.18203919,  -0.36879904, 295.46855054, 228.84907066,
#         -4.39572416])
# [ 42.18203919  -0.36879904 295.46855054 228.84907066  -4.39572416]
# run : 17
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725529618443
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.27799982e-03,  2.98361158e-01,  3.55271086e-06,  0.00000000e+00,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 600
#       nit: 67
#      njev: 100
#    status: 0
#   success: True
#         x: array([ 33.21798051,  -0.33314135, 232.29733162, 220.16699881,
#         -3.06102415])
# [ 33.21798051  -0.33314135 232.29733162 220.16699881  -3.06102415]
# run : 18
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464254725788
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.04485301e-04,  1.33496769e-02, -1.56319278e-05,  4.68957834e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 606
#       nit: 65
#      njev: 101
#    status: 0
#   success: True
#         x: array([ 1.59125029e+01, -2.11410178e-01,  1.48015506e+02,  2.48301994e+02,
#        -9.81150854e-01])
# [ 1.59125029e+01 -2.11410178e-01  1.48015506e+02  2.48301994e+02
#  -9.81150854e-01]
# run : 19
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.047263097194055
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.58850697e-03,  1.81170634e-01,  8.95283137e-05, -9.87653619e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 636
#       nit: 42
#      njev: 106
#    status: 0
#   success: True
#         x: array([ 33.23572683,  -0.33327703, 232.37837463, 220.16626395,
#         -3.28416016])
# [ 33.23572683  -0.33327703 232.37837463 220.16626395  -3.28416016]
# run : 20
# Optimisation successful
# Remaining Error:  53.02
#       fun: 53.023462460975395
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.97530864e-04, -1.58884461e-02,  6.39487955e-05, -1.14397290e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 678
#       nit: 46
#      njev: 113
#    status: 0
#   success: True
#         x: array([ 20.8712665 ,  -0.32758406, 191.77845224, 256.09019339,
#         -2.50798318])
# [ 20.8712665   -0.32758406 191.77845224 256.09019339  -2.50798318]
# run : 21
# Optimisation successful
# Remaining Error:  120.82
#       fun: 120.81518613880189
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00976001,  0.20959448,  0.00713961,  0.00033538, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 252
#       nit: 25
#      njev: 42
#    status: 0
#   success: True
#         x: array([ 8.77646265e+02, -1.24149172e-01,  1.64176494e+03,  4.24470505e+02,
#        -3.29780786e+00])
# [ 8.77646265e+02 -1.24149172e-01  1.64176494e+03  4.24470505e+02
#  -3.29780786e+00]
# run : 22
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83166683278389
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.52109424e-02, -4.72626738e-01, -2.70006025e-05,  3.19743977e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 690
#       nit: 55
#      njev: 115
#    status: 0
#   success: True
#         x: array([ 42.52417188,  -0.35437224, 289.80083291, 223.80288414,
#         -4.94377949])
# [ 42.52417188  -0.35437224 289.80083291 223.80288414  -4.94377949]
# run : 23
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611886879656
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271338e-06, -6.70752343e-04,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 750
#       nit: 78
#      njev: 125
#    status: 0
#   success: True
#         x: array([ 25.73395382,  -0.30701052, 191.40942866, 225.3599542 ,
#         -2.95498319])
# [ 25.73395382  -0.30701052 191.40942866 225.3599542   -2.95498319]
# run : 24
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.,  0.,  0.,  0., -0.])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 0.        , -2.93548022, 90.52390122,  0.        , -1.06420659])
# [ 0.         -2.93548022 90.52390122  0.         -1.06420659]
# run : 25
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.6546424471918
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.10542677e-06, -1.19371180e-04, -2.84216869e-06,  1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 522
#       nit: 54
#      njev: 87
#    status: 0
#   success: True
#         x: array([ 1.59122869e+01, -2.11418398e-01,  1.48014342e+02,  2.48301950e+02,
#        -4.72038967e-01])
# [ 1.59122869e+01 -2.11418398e-01  1.48014342e+02  2.48301950e+02
#  -4.72038967e-01]
# run : 26
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337807919108
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.76356692e-03,  1.14452092e-01,  1.42108434e-04, -4.40536147e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 762
#       nit: 62
#      njev: 127
#    status: 0
#   success: True
#         x: array([ 17.45094663,  -0.28668374, 166.70761436, 262.0311141 ,
#         -1.85743385])
# [ 17.45094663  -0.28668374 166.70761436 262.0311141   -1.85743385]
# run : 27
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464245863375
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.54747313e-05,  1.40829570e-03,  7.10542172e-06,  4.26325303e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 744
#       nit: 67
#      njev: 124
#    status: 0
#   success: True
#         x: array([ 1.59124104e+01, -2.11420932e-01,  1.48017076e+02,  2.48302939e+02,
#        -1.43774104e-01])
# [ 1.59124104e+01 -2.11420932e-01  1.48017076e+02  2.48302939e+02
#  -1.43774104e-01]
# run : 28
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.01053309, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 5.56511839e+02, -2.93548022e+00,  1.42312793e+03,  0.00000000e+00,
#        -1.61294105e-01])
# [ 5.56511839e+02 -2.93548022e+00  1.42312793e+03  0.00000000e+00
#  -1.61294105e-01]
# run : 29
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464275252018
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.95807798e-05, -9.26974054e-03, -1.42108434e-06,  5.68433738e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 732
#       nit: 56
#      njev: 122
#    status: 0
#   success: True
#         x: array([ 1.59129502e+01, -2.11466813e-01,  1.48024854e+02,  2.48311497e+02,
#        -3.77280947e-01])
# [ 1.59129502e+01 -2.11466813e-01  1.48024854e+02  2.48311497e+02
#  -3.77280947e-01]
# run : 30
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464262062847
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.55271338e-05, -5.32054401e-03, -2.41584339e-05,  1.70530121e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 936
#       nit: 89
#      njev: 156
#    status: 0
#   success: True
#         x: array([ 1.59114491e+01, -2.11437465e-01,  1.48012544e+02,  2.48314526e+02,
#        -7.84676584e-01])
# [ 1.59114491e+01 -2.11437465e-01  1.48012544e+02  2.48314526e+02
#  -7.84676584e-01]
# run : 31
# Optimisation successful
# Remaining Error:  66.68
#       fun: 66.68199713134337
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.98951950e-05, -1.06439302e-03, -1.42108434e-06,  2.84216869e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 618
#       nit: 60
#      njev: 103
#    status: 0
#   success: True
#         x: array([ 1.52633877e+01, -2.22985937e-01,  1.49433649e+02,  2.58432379e+02,
#        -4.05125958e-01])
# [ 1.52633877e+01 -2.22985937e-01  1.49433649e+02  2.58432379e+02
#  -4.05125958e-01]
# run : 32
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464248115904
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.26849631e-05, -4.24194013e-03, -1.42108434e-06,  0.00000000e+00,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 948
#       nit: 72
#      njev: 158
#    status: 0
#   success: True
#         x: array([ 1.59122830e+01, -2.11433324e-01,  1.48016775e+02,  2.48306328e+02,
#        -6.75954794e-02])
# [ 1.59122830e+01 -2.11433324e-01  1.48016775e+02  2.48306328e+02
#  -6.75954794e-02]
# run : 33
# Optimisation successful
# Remaining Error:  127.12
#       fun: 127.11861819439213
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.01228102, -0.09825669,  0.01534504, -0.03715283, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 408
#       nit: 20
#      njev: 68
#    status: 0
#   success: True
#         x: array([ 5.43026566e+01, -7.39195765e-02,  1.97565817e+03,  6.31213303e+02,
#        -4.83366061e-01])
# [ 5.43026566e+01 -7.39195765e-02  1.97565817e+03  6.31213303e+02
#  -4.83366061e-01]
# run : 34
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611888415238
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-4.19220179e-05, -3.14912541e-03,  7.10542172e-07, -4.97379520e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 588
#       nit: 56
#      njev: 98
#    status: 0
#   success: True
#         x: array([ 25.73367804,  -0.30702092, 191.41140794, 225.36340465,
#         -2.39635269])
# [ 25.73367804  -0.30702092 191.41140794 225.36340465  -2.39635269]
# run : 35
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725629980591
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.58566480e-03, -1.34514266e-01, -5.75539159e-05,  1.59161447e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 786
#       nit: 64
#      njev: 131
#    status: 0
#   success: True
#         x: array([ 33.21453153,  -0.33311504, 232.29689222, 220.1814307 ,
#         -3.79426866])
# [ 33.21453153  -0.33311504 232.29689222 220.1814307   -3.79426866]
# run : 36
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83262011740224
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.69455547e-02, -1.11772991e+00,  1.27897591e-05, -1.91846386e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 690
#       nit: 63
#      njev: 115
#    status: 0
#   success: True
#         x: array([ 42.45222526,  -0.35739973, 290.55623591, 224.66739847,
#         -4.15994885])
# [ 42.45222526  -0.35739973 290.55623591 224.66739847  -4.15994885]
# run : 37
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464274876032
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.83693046e-05, -1.17964305e-02, -3.12638556e-05, -1.42108434e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 570
#       nit: 51
#      njev: 95
#    status: 0
#   success: True
#         x: array([ 1.59134910e+01, -2.11433229e-01,  1.48007525e+02,  2.48288266e+02,
#        -4.98889840e-01])
# [ 1.59134910e+01 -2.11433229e-01  1.48007525e+02  2.48288266e+02
#  -4.98889840e-01]
# run : 38
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.02855813, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 840.42362211,   -2.93548022, 1524.69971333,    0.        ,
#          -3.43691732])
# [ 840.42362211   -2.93548022 1524.69971333    0.           -3.43691732]
# run : 39
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611886716377
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-5.68434142e-06,  6.03961326e-05,  7.10542172e-07, -7.10542172e-07,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 726
#       nit: 72
#      njev: 121
#    status: 0
#   success: True
#         x: array([ 25.73395599,  -0.3070088 , 191.41068318, 225.36018863,
#         -2.02079333])
# [ 25.73395599  -0.3070088  191.41068318 225.36018863  -2.02079333]
# run : 40
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337919603557
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.67474909e-03,  2.23583641e-01, -1.38555724e-04, -7.10542172e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 684
#       nit: 63
#      njev: 114
#    status: 0
#   success: True
#         x: array([ 17.44663508,  -0.28664901, 166.61683119, 262.01709177,
#         -1.68330303])
# [ 17.44663508  -0.28664901 166.61683119 262.01709177  -1.68330303]
# run : 41
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464244759184
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.84217071e-06, -8.52651283e-05, -2.84216869e-06, -1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 660
#       nit: 67
#      njev: 110
#    status: 0
#   success: True
#         x: array([ 1.59123143e+01, -2.11415164e-01,  1.48013216e+02,  2.48300240e+02,
#        -8.77788549e-01])
# [ 1.59123143e+01 -2.11415164e-01  1.48013216e+02  2.48300240e+02
#  -8.77788549e-01]
# run : 42
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.6547208052497
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.55226930e-03,  1.53676183e-02, -8.81072293e-05,  1.23634338e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 780
#       nit: 66
#      njev: 130
#    status: 0
#   success: True
#         x: array([ 1.59209298e+01, -2.12340522e-01,  1.48172999e+02,  2.48503772e+02,
#        -3.73802649e-01])
# [ 1.59209298e+01 -2.12340522e-01  1.48172999e+02  2.48503772e+02
#  -3.73802649e-01]
# run : 43
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337597681386
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.45377032e-03, -1.45894319e-01,  5.11590364e-05, -7.81596389e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 648
#       nit: 45
#      njev: 108
#    status: 0
#   success: True
#         x: array([ 17.45065667,  -0.28668149, 166.67249078, 262.01103575,
#         -1.78484505])
# [ 17.45065667  -0.28668149 166.67249078 262.01103575  -1.78484505]
# run : 44
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.08697043, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 882.58867529,   -2.93548022, 1876.45669205,    0.        ,
#          -1.87954952])
# [ 882.58867529   -2.93548022 1876.45669205    0.           -1.87954952]
# run : 45
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.8661188686343
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-4.97379874e-06, -3.60245167e-04,  4.26325303e-06, -2.84216869e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 648
#       nit: 66
#      njev: 108
#    status: 0
#   success: True
#         x: array([ 25.73418831,  -0.30700768, 191.41014785, 225.35857481,
#         -2.60793157])
# [ 25.73418831  -0.30700768 191.41014785 225.35857481  -2.60793157]
# run : 46
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.393375455533516
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.74011902e-03,  1.72464354e-01,  0.00000000e+00, -1.70530121e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 882
#       nit: 58
#      njev: 147
#    status: 0
#   success: True
#         x: array([ 17.44822228,  -0.28666262, 166.66169767, 262.02925196,
#         -1.91805413])
# [ 17.44822228  -0.28666262 166.66169767 262.02925196  -1.91805413]
# run : 47
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39338162823397
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 9.99023004e-04, -7.32429584e-01, -1.30029217e-04, -7.10542172e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 744
#       nit: 64
#      njev: 124
#    status: 0
#   success: True
#         x: array([ 17.44128992,  -0.28660887, 166.61099196, 262.05718902,
#         -1.16598263])
# [ 17.44128992  -0.28660887 166.61099196 262.05718902  -1.16598263]
# run : 48
# Optimisation successful
# Remaining Error:  66.68
#       fun: 66.68199712629476
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.26325606e-06, -2.03215223e-04,  2.84216869e-06,  2.84216869e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 702
#       nit: 61
#      njev: 117
#    status: 0
#   success: True
#         x: array([ 1.52635536e+01, -2.22985371e-01,  1.49434638e+02,  2.58430930e+02,
#        -1.73632555e-01])
# [ 1.52635536e+01 -2.22985371e-01  1.49434638e+02  2.58430930e+02
#  -1.73632555e-01]
# run : 49
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.393376100575495
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.37321254e-03,  1.35975142e-01, -7.24753016e-05,  2.70006025e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 792
#       nit: 72
#      njev: 132
#    status: 0
#   success: True
#         x: array([ 17.4496851 ,  -0.28667396, 166.64899282, 262.0137803 ,
#         -1.89222377])
# [ 17.4496851   -0.28667396 166.64899282 262.0137803   -1.89222377]
# run : 50
# Optimisation successful
# Remaining Error:  80.25
#       fun: 80.2489226570455
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.27130205e-02,  1.47089452e-01, -6.67909642e-05, -3.33955295e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 270
#       nit: 28
#      njev: 45
#    status: 0
#   success: True
#         x: array([ 4.93905419e+02, -1.70116111e-01,  2.41962961e+02,  1.21386151e+02,
#        -4.31774221e+00])
# [ 4.93905419e+02 -1.70116111e-01  2.41962961e+02  1.21386151e+02
#  -4.31774221e+00]
# run : 51
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725585536893
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.98951950e-03,  9.00186592e-02,  5.54222894e-05, -5.61328316e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 690
#       nit: 54
#      njev: 115
#    status: 0
#   success: True
#         x: array([ 33.21502462,  -0.3331188 , 232.31069829, 220.17456459,
#         -3.20411326])
# [ 33.21502462  -0.3331188  232.31069829 220.17456459  -3.20411326]
# run : 52
# Optimisation successful
# Remaining Error:  56.11
#       fun: 56.11280222636158
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00635794, -1.16590968, -0.01153494, -0.00307949, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 732
#       nit: 68
#      njev: 122
#    status: 0
#   success: True
#         x: array([ 33.57608444,  -0.32112492, 221.74116367, 212.86091005,
#         -3.9628976 ])
# [ 33.57608444  -0.32112492 221.74116367 212.86091005  -3.9628976 ]
# run : 53
# Optimisation successful
# Remaining Error:  114.27
#       fun: 114.27342046024576
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00188862,  0.03073666,  0.01326882, -0.00042206, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 624
#       nit: 29
#      njev: 104
#    status: 0
#   success: True
#         x: array([ 2.89059718e+01, -3.97937585e-01,  1.24114890e+03,  7.28634949e+02,
#        -5.89811965e-01])
# [ 2.89059718e+01 -3.97937585e-01  1.24114890e+03  7.28634949e+02
#  -5.89811965e-01]
# run : 54
# Optimisation successful
# Remaining Error:  71.23
#       fun: 71.23099661782277
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.21616485e-02, -5.77846038e-01,  2.91237025e-02,  1.98951808e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 348
#       nit: 23
#      njev: 58
#    status: 0
#   success: True
#         x: array([ 4.55914277e+01, -4.58517948e-01,  5.68850878e+02,  3.51997112e+02,
#        -4.05037040e+00])
# [ 4.55914277e+01 -4.58517948e-01  5.68850878e+02  3.51997112e+02
#  -4.05037040e+00]
# run : 55
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611886856257
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.06581402e-05,  5.04485343e-05,  7.10542172e-07,  7.10542172e-07,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 672
#       nit: 79
#      njev: 112
#    status: 0
#   success: True
#         x: array([ 25.73407254,  -0.30701214, 191.41179506, 225.36083177,
#         -2.32301923])
# [ 25.73407254  -0.30701214 191.41179506 225.36083177  -2.32301923]
# run : 56
# Optimisation successful
# Remaining Error:  113.52
#       fun: 113.51770539871913
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.16102591e-02, -6.02089756e-01,  1.57386880e-02,  3.82271689e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 366
#       nit: 16
#      njev: 61
#    status: 0
#   success: True
#         x: array([ 7.78443440e+02, -1.40756841e-01,  1.05869845e+03,  2.98928587e+02,
#        -3.51957084e+00])
# [ 7.78443440e+02 -1.40756841e-01  1.05869845e+03  2.98928587e+02
#  -3.51957084e+00]
# run : 57
# Optimisation successful
# Remaining Error:  121.57
#       fun: 121.56770135222672
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.02964384,  5.30005196,  0.01639382, -0.02489456, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 612
#       nit: 31
#      njev: 102
#    status: 0
#   success: True
#         x: array([ 4.80479454e+01, -1.32080100e-01,  1.47547433e+03,  5.44249941e+02,
#        -9.57274095e-01])
# [ 4.80479454e+01 -1.32080100e-01  1.47547433e+03  5.44249941e+02
#  -9.57274095e-01]
# run : 58
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725533220198
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.24318323e-03,  2.96891045e-01, -7.81596389e-06, -4.97379520e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 468
#       nit: 44
#      njev: 78
#    status: 0
#   success: True
#         x: array([ 33.21728289,  -0.33313603, 232.29057776, 220.16502189,
#         -3.46350152])
# [ 33.21728289  -0.33313603 232.29057776 220.16502189  -3.46350152]
# run : 59
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83206948495229
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.64018119e-02, -5.83973759e-01, -2.93453917e-04, -3.33954821e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 768
#       nit: 61
#      njev: 128
#    status: 0
#   success: True
#         x: array([ 42.49401906,  -0.35564065, 289.71739238, 224.00314096,
#         -4.60987767])
# [ 42.49401906  -0.35564065 289.71739238 224.00314096  -4.60987767]
# run : 60
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611892790922
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-4.90274447e-05, -1.27329258e-03,  1.63424700e-05, -7.10542172e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 714
#       nit: 65
#      njev: 119
#    status: 0
#   success: True
#         x: array([ 25.73407217,  -0.3070251 , 191.4192919 , 225.36585563,
#         -2.46696655])
# [ 25.73407217  -0.3070251  191.4192919  225.36585563  -2.46696655]
# run : 61
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.00499654, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 735.02453139,   -2.93548022, 1614.5029646 ,    0.        ,
#          -4.62321261])
# [ 735.02453139   -2.93548022 1614.5029646     0.           -4.62321261]
# run : 62
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83338428939598
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.01200817, -1.10684866, -0.00149001,  0.00117026, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 744
#       nit: 61
#      njev: 124
#    status: 0
#   success: True
#         x: array([ 42.46661294,  -0.35679403, 289.04054307, 224.0192924 ,
#         -4.48352903])
# [ 42.46661294  -0.35679403 289.04054307 224.0192924   -4.48352903]
# run : 63
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65464280448498
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.62003730e-04, -9.55537872e-03, -2.41584339e-05,  8.52650607e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 642
#       nit: 62
#      njev: 107
#    status: 0
#   success: True
#         x: array([ 1.59107049e+01, -2.11441553e-01,  1.48011940e+02,  2.48321888e+02,
#        -9.31401330e-01])
# [ 1.59107049e+01 -2.11441553e-01  1.48011940e+02  2.48321888e+02
#  -9.31401330e-01]
# run : 64
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.08317897, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 992.54633194,   -2.93548022, 1800.86973916,    0.        ,
#          -2.05268068])
# [ 992.54633194   -2.93548022 1800.86973916    0.           -2.05268068]
# run : 65
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.0473018599042
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.15250022e-03, -4.24823554e-01,  4.02877412e-04, -1.22142199e-03,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 858
#       nit: 63
#      njev: 143
#    status: 0
#   success: True
#         x: array([ 33.21419656,  -0.33311248, 232.20316502, 220.06576466,
#         -3.51136492])
# [ 33.21419656  -0.33311248 232.20316502 220.06576466  -3.51136492]
# run : 66
# Optimisation successful
# Remaining Error:  453.04
#       fun: 453.03553908023446
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.41060515e-05,  0.00000000e+00,  0.00000000e+00, -2.95017110e-03,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 234
#       nit: 31
#      njev: 39
#    status: 0
#   success: True
#         x: array([ 5.77237640e+00, -2.93548022e+00,  4.43622230e+02,  1.00000000e+03,
#        -9.91080441e-02])
# [ 5.77237640e+00 -2.93548022e+00  4.43622230e+02  1.00000000e+03
#  -9.91080441e-02]
# run : 67
# Optimisation successful
# Remaining Error:  67.84
#       fun: 67.83673941188118
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.0354504 , -0.3348049 ,  0.03239646, -0.0006608 , -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 336
#       nit: 28
#      njev: 56
#    status: 0
#   success: True
#         x: array([ 4.40684706e+01, -4.25713008e-01,  4.58307486e+02,  3.01570547e+02,
#        -4.80588034e+00])
# [ 4.40684706e+01 -4.25713008e-01  4.58307486e+02  3.01570547e+02
#  -4.80588034e+00]
# run : 68
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725529904066
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.23181455e-03,  2.96483194e-01,  4.97379520e-06, -1.27897591e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1092
#       nit: 89
#      njev: 182
#    status: 0
#   success: True
#         x: array([ 33.21770404,  -0.33313926, 232.29578892, 220.16608395,
#         -3.15358987])
# [ 33.21770404  -0.33313926 232.29578892 220.16608395  -3.15358987]
# run : 69
# Optimisation successful
# Remaining Error:  120.07
#       fun: 120.06853743604839
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.05016712,  0.24398616,  0.0115166 , -0.01235207, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 270
#       nit: 23
#      njev: 45
#    status: 0
#   success: True
#         x: array([ 1.82479061e+02, -1.05651484e-01,  1.43425053e+03,  3.99783924e+02,
#        -1.81320105e+00])
# [ 1.82479061e+02 -1.05651484e-01  1.43425053e+03  3.99783924e+02
#  -1.81320105e+00]
# run : 70
# Optimisation successful
# Remaining Error:  69.72
#       fun: 69.71509965442335
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.30029310e-03,  9.09186327e-01,  3.66597128e-02, -6.55119883e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 588
#       nit: 33
#      njev: 98
#    status: 0
#   success: True
#         x: array([ 3.95447737e+01, -4.82482811e-01,  5.87913944e+02,  3.88034562e+02,
#        -3.34401307e+00])
# [ 3.95447737e+01 -4.82482811e-01  5.87913944e+02  3.88034562e+02
#  -3.34401307e+00]
# run : 71
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.86611886832621
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-4.97379874e-06, -4.26325642e-06,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 588
#       nit: 46
#      njev: 98
#    status: 0
#   success: True
#         x: array([ 25.73384543,  -0.30700717, 191.40917358, 225.35978151,
#         -2.60897227])
# [ 25.73384543  -0.30700717 191.40917358 225.35978151  -2.60897227]
# run : 72
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337737982339
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 3.40989431e-03,  2.64377320e-01, -1.69109037e-04,  1.47792772e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 660
#       nit: 56
#      njev: 110
#    status: 0
#   success: True
#         x: array([ 17.44875681,  -0.28666675, 166.63955203, 262.02522048,
#         -1.24321691])
# [ 17.44875681  -0.28666675 166.63955203 262.02522048  -1.24321691]
# run : 73
# Optimisation successful
# Remaining Error:  118.92
#       fun: 118.91954371128763
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.02158201,  0.06026397,  0.01045219,  0.00589466, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 294
#       nit: 26
#      njev: 49
#    status: 0
#   success: True
#         x: array([ 4.99267981e+02, -1.25913139e-01,  1.24094392e+03,  3.39026241e+02,
#        -2.21508301e+00])
# [ 4.99267981e+02 -1.25913139e-01  1.24094392e+03  3.39026241e+02
#  -2.21508301e+00]
# run : 74
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65472639804707
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.79474198e-03, -2.33490027e-01, -1.47792772e-04,  3.42481327e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 918
#       nit: 74
#      njev: 153
#    status: 0
#   success: True
#         x: array([ 1.59218807e+01, -2.12376557e-01,  1.48196068e+02,  2.48530094e+02,
#        -6.96210168e-01])
# [ 1.59218807e+01 -2.12376557e-01  1.48196068e+02  2.48530094e+02
#  -6.96210168e-01]
# run : 75
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.866118867107005
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.68434142e-06, -8.52651283e-05,  1.42108434e-06,  7.10542172e-07,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 528
#       nit: 56
#      njev: 88
#    status: 0
#   success: True
#         x: array([ 25.73404883,  -0.30700994, 191.41071942, 225.36001718,
#         -2.55994569])
# [ 25.73404883  -0.30700994 191.41071942 225.36001718  -2.55994569]
# run : 76
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.047255735554685
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.53663736e-03, -2.05328377e-01, -6.39487955e-06,  5.47117473e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 804
#       nit: 63
#      njev: 134
#    status: 0
#   success: True
#         x: array([ 33.22139085,  -0.33316747, 232.32136379, 220.17453832,
#         -3.19451958])
# [ 33.22139085  -0.33316747 232.32136379 220.17453832  -3.19451958]
# run : 77
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725556817506
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.31494804e-03,  2.96525116e-01, -2.98427712e-05,  1.56319278e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 684
#       nit: 53
#      njev: 114
#    status: 0
#   success: True
#         x: array([ 33.217077  ,  -0.33313439, 232.27778118, 220.16105673,
#         -3.49017489])
# [ 33.217077    -0.33313439 232.27778118 220.16105673  -3.49017489]
# run : 78
# Optimisation successful
# Remaining Error:  52.87
#       fun: 52.8661188671913
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.26325606e-06, -3.90798505e-05,  7.10542172e-07, -7.10542172e-07,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 462
#       nit: 51
#      njev: 77
#    status: 0
#   success: True
#         x: array([ 25.73402069,  -0.30700783, 191.40986315, 225.35937573,
#         -2.59014317])
# [ 25.73402069  -0.30700783 191.40986315 225.35937573  -2.59014317]
# run : 79
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39347695929074
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00219984,  0.24152627, -0.00061391,  0.00045617, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 978
#       nit: 85
#      njev: 163
#    status: 0
#   success: True
#         x: array([ 17.41537007,  -0.28640773, 166.49284301, 262.23535997,
#         -1.42227808])
# [ 17.41537007  -0.28640773 166.49284301 262.23535997  -1.42227808]
# run : 80
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83169650993329
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 4.11660005e-02, -9.33973610e-01, -2.74269278e-04,  9.10915065e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 600
#       nit: 50
#      njev: 100
#    status: 0
#   success: True
#         x: array([ 42.52393957,  -0.35438202, 289.93316176, 223.90843866,
#         -4.60882849])
# [ 42.52393957  -0.35438202 289.93316176 223.90843866  -4.60882849]
# run : 81
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725689058099
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.14654943e-03, -1.59363367e-01, -9.94759041e-06,  5.89750003e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 756
#       nit: 70
#      njev: 126
#    status: 0
#   success: True
#         x: array([ 33.20983146,  -0.3330791 , 232.28270825, 220.17772781,
#         -3.2912489 ])
# [ 33.20983146  -0.3330791  232.28270825 220.17772781  -3.2912489 ]
# run : 82
# Optimisation successful
# Remaining Error:  137.09
#       fun: 137.08792340195032
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00753743,  0.00296438,  0.00493406,  0.00050875, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 240
#       nit: 16
#      njev: 40
#    status: 0
#   success: True
#         x: array([ 9.11684534e+02,  1.58335347e-02,  1.82159318e+03,  3.94720418e+02,
#        -1.38044296e+00])
# [ 9.11684534e+02  1.58335347e-02  1.82159318e+03  3.94720418e+02
#  -1.38044296e+00]
# run : 83
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.10336407, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 9.98544216e+02, -2.93548022e+00,  1.49426115e+03,  0.00000000e+00,
#        -1.49272848e+00])
# [ 9.98544216e+02 -2.93548022e+00  1.49426115e+03  0.00000000e+00
#  -1.49272848e+00]
# run : 84
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.047255303220155
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.22044587e-03, -4.92454433e-01,  1.42108434e-05, -1.56319278e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 624
#       nit: 51
#      njev: 104
#    status: 0
#   success: True
#         x: array([ 33.21793013,  -0.33314102, 232.30292035, 220.1685908 ,
#         -3.70691586])
# [ 33.21793013  -0.33314102 232.30292035 220.1685908   -3.70691586]
# run : 85
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337717419582
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.07904787e-03,  2.00827799e-02, -6.11066268e-05, -3.26849399e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1026
#       nit: 69
#      njev: 171
#    status: 0
#   success: True
#         x: array([ 17.45178122,  -0.28669021, 166.64627455, 261.99073819,
#         -1.70766842])
# [ 17.45178122  -0.28669021 166.64627455 261.99073819  -1.70766842]
# run : 86
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.       ,  0.       ,  0.       ,  0.1052797, -0.       ])
# ...
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 528
#       nit: 43
#      njev: 88
#    status: 0
#   success: True
#         x: array([ 9.82468708e+00, -3.96636928e-01,  3.52311626e+02,  6.56634646e+02,
#        -8.56403942e-01])
# [ 9.82468708e+00 -3.96636928e-01  3.52311626e+02  6.56634646e+02
#  -8.56403942e-01]
# run : 272
# Optimisation successful
# Remaining Error:  53.03
#       fun: 53.02619654083729
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 6.39488409e-06,  3.59534624e-04, -2.84216869e-06,  2.13162652e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 504
#       nit: 51
#      njev: 84
#    status: 0
#   success: True
#         x: array([ 22.65790094,  -0.31093554, 189.53498642, 240.6734968 ,
#         -2.91321642])
# [ 22.65790094  -0.31093554 189.53498642 240.6734968   -2.91321642]
# run : 273
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.01369926, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 5.06861909e+02, -2.93548022e+00,  1.84467532e+03,  0.00000000e+00,
#        -5.25739746e-01])
# [ 5.06861909e+02 -2.93548022e+00  1.84467532e+03  0.00000000e+00
#  -5.25739746e-01]
# run : 274
# Optimisation successful
# Remaining Error:  123.37
#       fun: 123.36654741124114
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.82154591e-02,  2.63138134e-01,  7.61283538e-03, -4.12114460e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 234
#       nit: 18
#      njev: 39
#    status: 0
#   success: True
#         x: array([ 5.63186972e+02, -1.00901415e-01,  1.57921680e+03,  4.04876592e+02,
#        -2.48547677e+00])
# [ 5.63186972e+02 -1.00901415e-01  1.57921680e+03  4.04876592e+02
#  -2.48547677e+00]
# run : 275
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337548243479
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.86304290e-03, -4.16660839e-01, -7.10542172e-06,  4.26325303e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 672
#       nit: 56
#      njev: 112
#    status: 0
#   success: True
#         x: array([ 17.44760505,  -0.28665784, 166.66146712, 262.03575116,
#         -1.22965258])
# [ 17.44760505  -0.28665784 166.66146712 262.03575116  -1.22965258]
# run : 276
# Optimisation successful
# Remaining Error:  53.02
#       fun: 53.023458383818884
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.25801581e-05, -3.31858985e-02,  7.10542172e-07, -1.49213856e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 768
#       nit: 53
#      njev: 128
#    status: 0
#   success: True
#         x: array([ 20.86301182,  -0.32755747, 191.76481785, 256.14282841,
#         -2.15641894])
# [ 20.86301182  -0.32755747 191.76481785 256.14282841  -2.15641894]
# run : 277
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83262046212013
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.80643041e-02, -8.87089869e-01, -2.13162652e-05,  6.96331329e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 786
#       nit: 46
#      njev: 131
#    status: 0
#   success: True
#         x: array([ 42.45338176,  -0.35735104, 290.55167359, 224.66160648,
#         -4.64874993])
# [ 42.45338176  -0.35735104 290.55167359 224.66160648  -4.64874993]
# run : 278
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.65471788916895
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.37703171e-03,  1.24174449e-02, -9.09493980e-05,  3.26849399e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 762
#       nit: 80
#      njev: 127
#    status: 0
#   success: True
#         x: array([ 1.59178035e+01, -2.12221949e-01,  1.48136270e+02,  2.48483766e+02,
#        -7.55060643e-02])
# [ 1.59178035e+01 -2.12221949e-01  1.48136270e+02  2.48483766e+02
#  -7.55060643e-02]
# run : 279
# Optimisation successful
# Remaining Error:  63.83
#       fun: 63.83271230085691
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.02618066, -0.14652386, -0.0006878 ,  0.00093507, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 822
#       nit: 59
#      njev: 137
#    status: 0
#   success: True
#         x: array([ 42.45227422,  -0.35739766, 290.12962475, 224.55274962,
#         -4.38091013])
# [ 42.45227422  -0.35739766 290.12962475 224.55274962  -4.38091013]
# run : 280
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.05432526, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 834.63797766,   -2.93548022, 1802.84264673,    0.        ,
#          -2.31746955])
# [ 834.63797766   -2.93548022 1802.84264673    0.           -2.31746955]
# run : 281
# Optimisation successful
# Remaining Error:  66.68
#       fun: 66.68199713260199
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.84217071e-06, -5.96855898e-05,  4.26325303e-06,  1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 648
#       nit: 58
#      njev: 108
#    status: 0
#   success: True
#         x: array([ 1.52635960e+01, -2.22987688e-01,  1.49436054e+02,  2.58431787e+02,
#        -3.47711903e-01])
# [ 1.52635960e+01 -2.22987688e-01  1.49436054e+02  2.58431787e+02
#  -3.47711903e-01]
# run : 282
# Optimisation successful
# Remaining Error:  53.02
#       fun: 53.02345856531537
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.53663736e-04,  4.23156621e-02,  1.63424700e-05, -9.94759041e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 906
#       nit: 70
#      njev: 151
#    status: 0
#   success: True
#         x: array([ 20.86472808,  -0.327563  , 191.77289135, 256.13652333,
#         -2.93690777])
# [ 20.86472808  -0.327563   191.77289135 256.13652333  -2.93690777]
# run : 283
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725664858215
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.44284572e-03, -1.68188308e-01,  4.54746990e-05,  9.23704824e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 540
#       nit: 49
#      njev: 90
#    status: 0
#   success: True
#         x: array([ 33.22315482,  -0.33318095, 232.34598768, 220.17952333,
#         -3.35920062])
# [ 33.22315482  -0.33318095 232.34598768 220.17952333  -3.35920062]
# run : 284
# Optimisation successful
# Remaining Error:  66.65
#       fun: 66.6546425174105
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-5.11590727e-05, -5.21112043e-03,  4.26325303e-06, -1.42108434e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 696
#       nit: 63
#      njev: 116
#    status: 0
#   success: True
#         x: array([ 1.59122052e+01, -2.11439687e-01,  1.48018895e+02,  2.48309598e+02,
#        -2.94956833e-01])
# [ 1.59122052e+01 -2.11439687e-01  1.48018895e+02  2.48309598e+02
#  -2.94956833e-01]
# run : 285
# Optimisation successful
# Remaining Error:  126.17
#       fun: 126.1654793105728
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00730153, -0.0004178 ,  0.00902683,  0.00177067, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 150
#       nit: 21
#      njev: 25
#    status: 0
#   success: True
#         x: array([ 9.56382215e+02,  9.40698122e-03,  1.35328415e+03,  3.17657382e+02,
#        -2.84503722e+00])
# [ 9.56382215e+02  9.40698122e-03  1.35328415e+03  3.17657382e+02
#  -2.84503722e+00]
# run : 286
# Optimisation successful
# Remaining Error:  97.99
#       fun: 97.98957451975718
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 9.32089221e-03, -1.93949745e-01,  3.95615671e-02,  1.32160844e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 162
#       nit: 15
#      njev: 27
#    status: 0
#   success: True
#         x: array([ 9.01426614e+02, -1.78903426e-01,  5.49660756e+02,  1.90008159e+02,
#        -4.41994282e+00])
# [ 9.01426614e+02 -1.78903426e-01  5.49660756e+02  1.90008159e+02
#  -4.41994282e+00]
# run : 287
# Optimisation successful
# Remaining Error:  53.02
#       fun: 53.02345899656279
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 7.01305622e-04,  4.85286478e-02, -1.49213856e-05,  3.05533134e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 786
#       nit: 64
#      njev: 131
#    status: 0
#   success: True
#         x: array([ 20.86627751,  -0.32756795, 191.77004925, 256.12819217,
#         -2.95308006])
# [ 20.86627751  -0.32756795 191.77004925 256.12819217  -2.95308006]
# run : 288
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337629118383
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00053149, -0.04012435,  0.00010232, -0.00012363, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 684
#       nit: 47
#      njev: 114
#    status: 0
#   success: True
#         x: array([ 17.44696468,  -0.28665287, 166.67206645, 262.03690804,
#         -1.8384674 ])
# [ 17.44696468  -0.28665287 166.67206645 262.03690804  -1.8384674 ]
# run : 289
# Optimisation successful
# Remaining Error:  87.13
#       fun: 87.12862385123469
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.00912194,  0.21036328, -0.00075602, -0.00086402, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 234
#       nit: 26
#      njev: 39
#    status: 0
#   success: True
#         x: array([ 7.04776226e+02, -8.57794225e-02,  1.87046620e+02,  1.03691576e+02,
#        -2.28858130e+00])
# [ 7.04776226e+02 -8.57794225e-02  1.87046620e+02  1.03691576e+02
#  -2.28858130e+00]
# run : 290
# Optimisation successful
# Remaining Error:  53.03
#       fun: 53.02619672998293
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.82644995e-05,  1.10020437e-02,  1.35003013e-05,  2.41584339e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 600
#       nit: 60
#      njev: 100
#    status: 0
#   success: True
#         x: array([ 22.65714205,  -0.31092055, 189.5427219 , 240.68046099,
#         -2.9491492 ])
# [ 22.65714205  -0.31092055 189.5427219  240.68046099  -2.9491492 ]
# run : 291
# Optimisation successful
# Remaining Error:  115.66
#       fun: 115.66029376354804
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.01001154,  0.02041389,  0.025895  ,  0.00130598, -0.        ])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 348
#       nit: 21
#      njev: 58
#    status: 0
#   success: True
#         x: array([ 8.43638632e+02, -8.87007782e-02,  7.68934832e+02,  2.24805012e+02,
#        -2.03092947e+00])
# [ 8.43638632e+02 -8.87007782e-02  7.68934832e+02  2.24805012e+02
#  -2.03092947e+00]
# run : 292
# Optimisation successful
# Remaining Error:  66.68
#       fun: 66.68199713165181
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-5.40012434e-05, -3.08943982e-03,  1.42108434e-06, -4.26325303e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 558
#       nit: 49
#      njev: 93
#    status: 0
#   success: True
#         x: array([ 1.52636143e+01, -2.22989578e-01,  1.49434234e+02,  2.58430528e+02,
#        -7.89610859e-01])
# [ 1.52636143e+01 -2.22989578e-01  1.49434234e+02  2.58430528e+02
#  -7.89610859e-01]
# run : 293
# Optimisation successful
# Remaining Error:  103.64
#       fun: 103.64052711065217
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.75846682e-02,  5.04817877e-01,  2.09908368e-02, -6.11066268e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 216
#       nit: 15
#      njev: 36
#    status: 0
#   success: True
#         x: array([ 4.08938901e+02, -1.93579696e-01,  8.89119606e+02,  2.75426315e+02,
#        -3.85426620e+00])
# [ 4.08938901e+02 -1.93579696e-01  8.89119606e+02  2.75426315e+02
#  -3.85426620e+00]
# run : 294
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04725532259274
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.18776090e-03, -9.87462557e-02,  6.39487955e-06, -2.27373495e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 786
#       nit: 68
#      njev: 131
#    status: 0
#   success: True
#         x: array([ 33.21714703,  -0.33313503, 232.29308894, 220.16534137,
#         -3.49651914])
# [ 33.21714703  -0.33313503 232.29308894 220.16534137  -3.49651914]
# run : 295
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.3933762504366
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.49613642e-03, -9.16458021e-03, -9.37915667e-05,  5.11590364e-05,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 930
#       nit: 78
#      njev: 155
#    status: 0
#   success: True
#         x: array([ 17.44887731,  -0.2866677 , 166.64499172, 262.01985158,
#         -1.72748153])
# [ 17.44887731  -0.2866677  166.64499172 262.01985158  -1.72748153]
# run : 296
# Optimisation successful
# Remaining Error:  55.39
#       fun: 55.39337568593898
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.08473221e-03, -2.54047450e-02, -2.20268073e-05, -4.26325303e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1074
#       nit: 84
#      njev: 179
#    status: 0
#   success: True
#         x: array([ 17.44996398,  -0.28667612, 166.65952772, 262.0149491 ,
#         -1.38053242])
# [ 17.44996398  -0.28667612 166.65952772 262.0149491   -1.38053242]
# run : 297
# Optimisation successful
# Remaining Error:  493.94
#       fun: 493.94365157679806
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        ,  0.        ,  0.        ,  0.08033112, -0.        ])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([ 7.31074606e+02, -2.93548022e+00,  1.68042231e+03,  0.00000000e+00,
#        -6.91050848e-01])
# [ 7.31074606e+02 -2.93548022e+00  1.68042231e+03  0.00000000e+00
#  -6.91050848e-01]
# run : 298
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.047255384620605
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.34692246e-03, -4.87687402e-01,  9.23704824e-06,  3.55271086e-06,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 648
#       nit: 53
#      njev: 108
#    status: 0
#   success: True
#         x: array([ 33.21988969,  -0.333156  , 232.31050177, 220.16968099,
#         -3.26191872])
# [ 33.21988969  -0.333156   232.31050177 220.16968099  -3.26191872]
# run : 299
# Optimisation successful
# Remaining Error:  56.05
#       fun: 56.04727761949462
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-4.95248246e-03, -4.74611284e-01,  3.41060243e-04, -2.44426507e-04,
#        -0.00000000e+00])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 612
#       nit: 53
#      njev: 102
#    status: 0
#   success: True
#         x: array([ 33.21077477,  -0.33308632, 232.44791321, 220.22968987,
#         -3.85989906])
# [ 33.21077477  -0.33308632 232.44791321 220.22968987  -3.85989906]

# %%
# model_para = np.load('model_parameters/scipymini_newmodel_alldatasetcombined.npy')
# print(f'(tauhp, thres, taulp1, taulp2, gain, shift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')

# %%
model_para = para_list[np.argmin(err_list)]
print(np.min(err_list))
print(np.min(err_list) / np.sum((T4_gcamp[10:100,:])**2))
#print(f'(thres, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
#print(f'(thres, tauhp, taulp1, gain1, taulp2, gain2, tshift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]:.2f}, {model_para[4]/100:.2f}, {model_para[5]:.2f}, {model_para[6]:.2f})')
#print(f'(tauhp, thres, taulp1, taulp2, gain, shift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f})')
#print(f'(tauhp, thres, taulp1, taulp2, gain1, gain2, shift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]/100:.2f}, {model_para[4]:.2f}, {model_para[5]:.2f}, {model_para[6]:.2f})')
print(f'(tauhp, thres, taulp, gain, shift) = ({model_para[0]/100:.2f}, {model_para[1]/100:.2f},{model_para[2]/100:.2f}, {model_para[3]:.2f}, {model_para[4]:.2f})')


#print(model_para/100) # (thres, taulp1, gain1, taulp2, gain2, tshift)
# Out:
# 52.86611886709021
# 0.10702864324367296
# (tauhp, thres, taulp, gain, shift) = (0.26, -0.00,1.91, 225.36, -2.44)

# %%
#model_p = fit_params()
#T4Ca_model = M_model(T4_arclight, model_para, plot=False)
#T4Ca_model = L_model(T4_arclight, model_para, plot=False)
T4Ca_model = S_model(T4_arclight, model_para, plot=False)
#plot_data([T4_Gcamp, T4Ca_model])

# %%
np.sum((T4_gcamp[10:100,:]-T4Ca_model[10:100,:])**2) / np.sum((T4_gcamp[10:100,:])**2)
# Out:
# 0.10702864324367296

# %%
# T4_gcamp = T4_gcamp / 100.0
# T4Ca_model = T4Ca_model / 100.0

# %%
#plotting Mi1 data
f,ax = plt.subplots(1,4,figsize=(10,5),sharey=True)
ax[0].plot(T4_gcamp[:,0]); ax[1].plot(T4_gcamp[:,1]); ax[2].plot(T4_gcamp[:,2]);ax[3].plot(T4_gcamp[:,3]);
ax[0].plot(T4Ca_model[:,0],color='g'); ax[1].plot(T4Ca_model[:,1],color='g'); ax[2].plot(T4Ca_model[:,2],color='g');ax[3].plot(T4Ca_model[:,3],color='g');

# %%
#plotting Mi1 data
f,ax = plt.subplots(1,4,figsize=(10,5),sharey=True)
ax[0].plot(T4_gcamp[:,4]); ax[1].plot(T4_gcamp[:,5]); ax[2].plot(T4_gcamp[:,6]);ax[3].plot(T4_gcamp[:,7]);
ax[0].plot(T4Ca_model[:,4],color='g'); ax[1].plot(T4Ca_model[:,5],color='g'); ax[2].plot(T4Ca_model[:,6],color='g');ax[3].plot(T4Ca_model[:,7],color='g');

# %%
velocity = [15, 30, 60, 120]
utils.plot_data([T4_gcamp[:,0:48], T4Ca_model[:,0:48]], ori=True,label=['GCaMP6','Model'],c=['r','g'],fig_size=(15,15),speed=velocity,savefig=False, title='Ori_Vel');
#utils.plot_data_twinaxis([T4_gcamp[0:107,0:48], T4Ca_model[0:107,0:48]],speed=velocity,c=['r','g'])
#plt.savefig('figures/scipymini_wholedatasetfit/Ori_Velocity_model.pdf',dpi=1000)

# %%
velocity=[15,30,60,120]
#utils.plot_data([T4_gcamp[:,48:], T4Ca_model[:,48:]], label=['GCaMP','Model'],c=['r','g'],speed=velocity)
utils.plot_data([T4_gcamp[:,96:104], T4Ca_model[:,96:104]], label=['GCaMP','Model'],c=['r','g'],speed=velocity)
#plt.savefig('figures/scipymini_wholedatasetfit/EdgePDND_model.pdf',dpi=1000)

# %%
# err_list = a['err']
# para_list = a['para']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5ffe49f08e2f> in <module>
# ----> 1 err_list = a['err']
#       2 para_list = a['para']
#
# NameError: name 'a' is not defined

# %%
err_array = np.array(err_list) / np.sum((T4_gcamp[10:100,:])**2)

# %%
idx = np.argpartition(err_list, 10)

# %%
err_array[idx[:10]]
# Out:
# array([0.10702864, 0.10702864, 0.10702864, 0.10702864, 0.10702864,
#        0.10702864, 0.10702864, 0.10702864, 0.10702864, 0.10702864])

# %%
from scipy.stats import sem
np.mean(err_array[idx[:10]]), np.std(err_array[idx[:10]]), sem(err_array[idx[:10]])
# Out:
# (0.10702864324454323, 1.0229252457463795e-12, 3.4097508191545975e-13)

# %%
para_array = np.array(para_list)
#para_array[:,:5] = para_array[:,:5]/100.0
para_array[:,:3] = para_array[:,:3]/100.0

# %%
#np.set_printoptions(suppress=True)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
para_array[idx[:10]]
# Out:
# array([[0.257, -0.003, 1.914, 225.360, -2.598],
#        [0.257, -0.003, 1.914, 225.360, -2.436],
#        [0.257, -0.003, 1.914, 225.360, -2.560],
#        [0.257, -0.003, 1.914, 225.359, -2.590],
#        [0.257, -0.003, 1.914, 225.359, -2.242],
#        [0.257, -0.003, 1.914, 225.361, -2.323],
#        [0.257, -0.003, 1.914, 225.360, -2.327],
#        [0.257, -0.003, 1.914, 225.360, -2.791],
#        [0.257, -0.003, 1.914, 225.360, -2.021],
#        [0.257, -0.003, 1.914, 225.360, -2.609]])

# %%
para_array[idx[:10],:5].shape
# Out:
# (10, 5)

# %%
np.std(para_array[idx[:10],:5],axis=0)
# Out:
# array([0.000, 0.000, 0.000, 0.000, 0.213])

# %%
f, ax = plt.subplots()
labels = ['HP', 'thres', 'LP', 'Gain1/100.0','shift']
#labels = ['HP', 'thres', 'LP1', 'LP2', 'Gain1/100.0','shift']
#labels = ['HP', 'thres', 'LP1', 'LP2', 'Gain1/100.0','Gain2/100.0','shift']
x_pos = np.arange(len(labels))
mean = np.mean(para_array[idx[:10],:],axis=0)
std = np.std(para_array[idx[:10],:],axis=0)
standard_error_mean = sem(para_array[idx[:10],:],axis=0)
ax.bar(x_pos, mean,
       yerr=std,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10);
ax.set_ylabel('mean with std')
ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
ax.set_title('Parameters mean with std')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
#plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
mean
# Out:
# array([0.257, -0.003, 1.914, 225.360, -2.450])

# %%
std
# Out:
# array([0.000, 0.000, 0.000, 0.000, 0.213])

# %%
standard_error_mean
# Out:
# array([0.000, 0.000, 0.000, 0.000, 0.071])

# %%
std/np.sqrt(9)
# Out:
# array([0.000, 0.000, 0.000, 0.000, 0.071])

# %%
para_array[idx[:10]]
# Out:
# array([[0.998, -0.009, 0.664, 64.326, -0.857],
#        [0.999, -0.009, 0.664, 64.320, -0.584],
#        [0.998, -0.009, 0.664, 64.326, -0.101],
#        [0.999, -0.009, 0.664, 64.319, -0.138],
#        [0.998, -0.009, 0.664, 64.323, -0.835],
#        [0.998, -0.009, 0.664, 64.323, -0.539],
#        [0.998, -0.009, 0.664, 64.326, -0.553],
#        [0.844, -0.010, 0.736, 69.312, -0.822],
#        [0.844, -0.010, 0.736, 69.310, -0.586],
#        [0.844, -0.010, 0.736, 69.312, -0.068]])

# %%
np.savez('model_parameters/err_para_list/Smodel_Tm3dataset.npz',err=err_list,para = para_list)

# %%
a = np.load('model_parameters/err_para_list/gcamp6_alldata.npz')

# %%
save_modeldata = True
if save_modeldata:
    np.save('/Volumes/Elements/Project_T4_VoltageCalcium/PaperFigures/data/modeldata/Tm3Ca_Smodel.npy',T4Ca_model)

# %%
save_para = True
if save_para:
    np.save('model_parameters/Smodel_Tm3dataset.npy',model_para)

# %%
a['err'].shape,a['para'].shape
# Out:
# ((300,), (300, 6))

# %%
a['err']
# Out:
# array([7952503.553, 1376590.076, 7952503.553, 1138915.179, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 1181497.695, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7553643.315,
#        7952503.553, 1175718.475, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 1191335.419, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 1221463.892,
#        7952503.553, 7952503.553, 7553643.315, 1376590.071, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 1376590.075,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        1686039.430, 1191350.288, 1686039.444, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        1686039.432, 7952503.553, 1191336.655, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7553643.315, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 1130796.860, 7952503.553,
#        1376590.071, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7553643.315, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 1686039.429, 7952503.553, 7952503.553, 7952503.553,
#        1222084.360, 7952503.553, 1376590.073, 7952503.553, 7952503.553,
#        1175718.475, 7952503.553, 1130796.860, 7952503.553, 7952503.553,
#        7952503.553, 1130796.865, 7952503.553, 7952503.553, 1191336.656,
#        1181262.857, 1178886.472, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 1686039.459,
#        1686039.452, 7952503.553, 7952503.553, 1376590.072, 7952503.553,
#        7952503.553, 1175718.475, 7952503.553, 1130796.865, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 1686039.462, 7952503.553, 7952503.553, 1376590.070,
#        7952503.553, 1376590.073, 7952503.553, 7952503.553, 7952503.553,
#        1376590.072, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 1130796.860, 1191335.419, 7952503.553, 7553643.315,
#        7952503.553, 7952503.553, 1130796.861, 7952503.553, 7952503.553,
#        7553643.315, 7952503.553, 1686039.428, 7952503.553, 1175718.475,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 1376590.096, 1686039.451,
#        7952503.553, 7952503.553, 1686039.463, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 1130796.860,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7553643.315,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        1686039.428, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 1686039.469, 7952503.553, 7952503.553, 1180436.932,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7553643.315, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7553643.315, 7952503.553, 7952503.553,
#        1191335.419, 7952503.553, 7952503.553, 7553643.315, 7952503.553,
#        7952503.553, 1130796.865, 7952503.553, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 1376590.070, 7952503.553, 7952503.553,
#        7952503.553, 7952503.553, 7952503.553, 7952503.553, 7952503.553,
#        1191335.420, 7952503.553, 7553643.315, 7952503.553, 7952503.553,
#        7553643.315, 1686039.430, 7952503.553, 1686039.441, 1376590.072,
#        7553643.315, 1175718.475, 1130796.860, 7952503.553, 7952503.553,
#        7952503.553, 1686039.429, 7553643.315, 7952503.553, 7952503.553,
#        1376590.070, 7952503.553, 7952503.553, 7952503.553, 7952503.553])

# %%
contrast = [100, 50, 20, 10]
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
#utils.plot_data_twinaxis([T4_arclight, T4_gcamp], fig_size=(15,15),speed=velocity,ylim1=(-0.04,0.10),ylim2=(-0.30,2.60),savefig=False, title='Ori_Vel');
utils.plot_data([T4_gcamp[:100,48:96], T4Ca_model[:100,48:96]], ori=True,contrast=True,label=['GCaMP','Model'],c=['r','g'], fig_size=(15,15),speed=contrast,savefig=False, title='Ori_Vel');
#plt.savefig('figures/scipymini_wholedatasetfit/Ori_Contrast_model.pdf',dpi=1000)

# %%
velocity=[15,30,60,120]
utils.plot_data([T4_gcamp[:,96:104], T4Ca_model[:,96:104]], label=['GCaMP','Model'],c=['r','g'],speed=velocity)
#plt.savefig('figures/scipymini_wholedatasetfit/EdgePDND_model.pdf',dpi=1000)

# %%
contrast = [100, 50, 20, 10]
utils.plot_data([T4_gcamp[:,104:112], T4Ca_model[:,104:112]], label=['GCaMP','Model'],speed=contrast,contrast=True,c=['r','g'])

# %%
data_list = [T4_gcamp[:,96:104], T4Ca_model[:,96:104]]
velocity = [15, 30, 60, 120]
utils.plot_modelpeaktuning(data_list, speed=velocity, ylim1=(0,600),ylim2=(0.0,600.0),color=['r','g'],title='',savefig=False)
#plt.savefig('figures/scipymini_wholedatasetfit/EdgePDND_peaktuning.pdf',dpi=1000)

# %%
velocity=[15,30,60,120]
utils.plot_data([T4_gcamp[:110,[16,17,18,19,40,41,42,43]], T4Ca_model[:110,[16,17,18,19,40,41,42,43]]], label=['GCaMP','Model'],c=['r','g'],speed=velocity)
#plt.savefig('figures/scipymini_wholedatasetfit/GratingsPDND_model.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:110,[16,17,18,19,40,41,42,43]], T4Ca_model[:110,[16,17,18,19,40,41,42,43]]]
velocity = [15, 30, 60, 120]
utils.plot_modelpeaktuning(data_list, speed=velocity, ylim1=(0,280),ylim2=(0.0,280),color=['r','g'],title='',savefig=False)
#plt.savefig('figures/scipymini_wholedatasetfit/GratingsPDND_peaktuning.pdf',dpi=1000)

# %%
contrast=[10,20,50,100]
utils.plot_data([T4_gcamp[:110,[67,66,65,64,91,90,89,88]], T4Ca_model[:110,[67,66,65,64,91,90,89,88]]], label=['GCaMP','Model'],c=['r','g'],speed=contrast,contrast=True)
#plt.savefig('figures/scipymini_wholedatasetfit/ContrastPDND_model.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:110,[67,66,65,64,91,90,89,88]], T4Ca_model[:110,[67,66,65,64,91,90,89,88]]]
contrast = [10,20,50,100]
utils.plot_modelpeaktuning(data_list, speed=contrast, contrast=True,ylim1=(0,280),ylim2=(0.0,280),color=['r','g'],title='',savefig=False)
#plt.savefig('figures/scipymini_wholedatasetfit/ContrastPDND_peaktuning.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:,0:48], T4Ca_model[:105,0:48]]
velocity = [15, 30, 60, 120]
peak_tuning = utils.calc_peaktuning(data_list, speed=velocity)
utils.plot_oripeaktuning(data_list,speed=velocity, label=['GCaMP','Model'],fig_size=(15,4), ylim1=(0.0,1.1),ylim2=(0.0,1.1),color=['r','g'],title='Speed_Ori_Tuning');
#plt.savefig('figures/scipymini_wholedatasetfit/OriVelPolar_model.pdf',dpi=1000)

# %%
utils.plot_Ldir_mag(peak_tuning, title='Ldir_Speed_Ori_Tuning',savefig=False);
#plt.savefig('figures/scipymini_wholedatasetfit/OriVelLdir_model.pdf',dpi=1000)

# %%
data_list = [T4_gcamp[:,48:96], T4Ca_model[:105,48:96]]
#velocity = [15, 30, 60, 120]
contrast = [10, 20, 50, 100]
peak_tuning = utils.calc_peaktuning(data_list, speed=contrast, contrast=True)
utils.plot_oripeaktuning(data_list,speed=contrast, label=['GCaMP','Model'],contrast=True,fig_size=(15,4), ylim1=(0.0,1.1),ylim2=(0.0,1.1),color=['r','g'],title='Speed_Ori_Tuning');
#plt.savefig('figures/scipymini_wholedatasetfit/OriContrastPolar_model.pdf',dpi=1000)

# %%
utils.plot_Ldir_mag(peak_tuning, title='',contrast=True,savefig=False);
#plt.savefig('figures/scipymini_wholedatasetfit/OriContrastLdir_model.pdf',dpi=1000)

# %%
save_modeldata = True
if save_modeldata:
    np.save('/Volumes/Elements/Project_T4_VoltageCalcium/PaperFigures/data/modeldata/T4Ca_model.npy',T4Ca_model)

# %%
save_para = True
if save_para:
    np.save('model_parameters/scipymini_newmodel_alldatasetcombined.npy',model_para)
