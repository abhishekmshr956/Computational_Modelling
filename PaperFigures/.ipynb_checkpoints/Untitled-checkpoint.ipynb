# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import utils
import utils_SEM
import pickle
from scipy.optimize import minimize

# %%
filename = 'data/forAbhi/Velocity_MeanSEM.mat'
data = scipy.io.loadmat(filename)
T4_arclight_gratings_mean = data['Arcmean'][10:,[16,17,18,19,40,41,42,43]] #taking PD(120deg) and ND(300deg) data
T4_arclight_gratings_sem = data['ArcSE'][10:,[16,17,18,19,40,41,42,43]] #taking PD(120deg) and ND(300deg) data

T4_gcamp_gratings_mean = data['Gmean'][10:,[16,17,18,19,40,41,42,43]] #taking PD(120deg) and ND(300deg) data
T4_gcamp_gratings_sem = data['GSE'][10:,[16,17,18,19,40,41,42,43]] #taking PD(120deg) and ND(300deg) data

# %%
fig = plt.figure()
ax1 = fig.add_subplot(5,5,1)
ax2 = fig.add_subplot(5,5,2,sharey=ax1)
plt.tight_layout()

# %%
f,ax = plt.subplots(5,5,sharey=True,sharex='col',figsize=(10,5));

# %%
utils_SEM.testplot_dataSEM_twinaxis([T4_arclight_gratings_mean, T4_gcamp_gratings_mean],
                                [T4_arclight_gratings_sem, T4_gcamp_gratings_sem], 
                               fig_size=(15,5), ylim1=(-0.04,0.10),ylim2=(-0.20,2.50), 
                                savefig=True, title='Gratings_SpeedPDND_withSEM')

# %%
f

# %%
f = plt.figure(figsize=(10,5))
f.add_subplot(251);
f.add_subplot(252);
f.add_subplot(253);
f.add_subplot(254);
f.add_subplot(255);
f.add_subplot(256);
f.add_subplot(257);

# %%
f.add_subplot(111)

# %%
f.add_subplot(251)

# %%
f.add_subplot(112)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c19314eab8fa> in <module>
# ----> 1 f.add_subplot(112)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      63             else:
#      64                 if num < 1 or num > rows*cols:
# ---> 65                     raise ValueError(
#      66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#
# ValueError: num must be 1 <= num <= 1, not 2

# %%
f
