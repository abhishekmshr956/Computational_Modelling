# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import utils
import pickle
from scipy.optimize import minimize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filename = 'data/forAbhi/Contrast_Data.mat'
data = scipy.io.loadmat(filename)
data_arc = data['data']
T4_arclight = data_arc[10:,[19,18,17,16,43,42,41,40]] #arranging columns so that contrast goes from 10% to 100%

data_gcamp = data['data2']
T4_gcamp = data_gcamp[10:,[19,18,17,16,43,42,41,40]] #arranging columns so that contrast goes from 10% to 100%

# %%
T4_arclight.shape, T4_gcamp.shape
# Out:
# ((103, 8), (103, 8))

# %%
# filename = 'data/T4c_ArcLight/ARCOri_Contrast_Mean.mat'
# data_arc = scipy.io.loadmat(filename)['PDmean']
# #T4_arclight = data_arc[10:,[16,17,18,19,40,41,42,43]]
# T4_arclight = data_arc[10:,[19,18,17,16,43,42,41,40]]

# filename = 'data/T4c_GCaMP/Ori_Mean_Contrast.mat'
# data_gcamp = scipy.io.loadmat(filename)['PDmean']
# #T4_gcamp = data_gcamp[10:,[16,17,18,19,40,41,42,43]]
# T4_gcamp = data_gcamp[10:,[19,18,17,16,43,42,41,40]]

# %%
#utils.plot_data_twinaxis([T4_arclight[10:,0:8], T4_gcamp[10:,0:8]], ylim=(-0.20,2.50), savefig=True, title='Gratings_SpeedPDND');
utils.plot_data_twinaxis([T4_arclight, T4_gcamp], speed=[10, 20, 50, 100],ylim1=(-0.04,0.10),ylim2=(-0.30,2.60), contrast=True,savefig=True, title='Contrast_PDND');

# %%
data_list = [T4_arclight, T4_gcamp]
contrast = [10, 20, 50, 100]
utils.plot_peaktuning(data_list, speed=contrast, ylim2=(0.0,2.6),color=['k','r'],title='Contrast_PeakTuning',savefig=True,contrast=True)
